# %%
import os
import json
import zipfile
import requests
import warnings
import numpy as np
import pandas as pd
from sqlalchemy import *
from datetime import date, datetime
from IPython.display import display, HTML
from sqlalchemy.ext.declarative import declarative_base
warnings.filterwarnings('ignore')
pd.pandas.set_option('display.max_rows', None)
pd.pandas.set_option('display.max_columns', None)
display(HTML('<style>.container{width : 100% ! important;}</style>'))

missed_matches = pd.read_excel('Missed Matches.xlsx')

url = 'mysql+mysqlconnector://{user}:{password}@{server}/{database}'.format(user = 'admin', password = 'adminroot', 
                                                                            server = 'indianpremierleague.cloqh08fxh1t.ap-south-1.rds.amazonaws.com',
                                                                            database = 'ipl')
engine = create_engine(url, echo = True)
base = declarative_base()

url = 'https://cricsheet.org/downloads/ipl_json.zip'
r = requests.get(url, allow_redirects = True)
open('ipl.zip', 'wb').write(r.content)
print('Data downloaded.')

with zipfile.ZipFile('ipl.zip', 'r') as zip_ref:
    zip_ref.extractall('Matches Extracted')
print('Data extracted.')

old = os.listdir('Matches')
new = os.listdir('Matches Extracted')
new = [file for file in new if file not in old]

for file in new:
    os.replace('Matches Extracted\\' + file, 'Matches New\\' + file)
print('Files moved to Matches New folder.')
    
files = os.listdir('Matches New\\')

match_id, city, date, player_of_match, venue, team1, team2, toss_winner = [], [], [], [], [], [], [], []
toss_decision, winner, result, result_margin, method, players, umpire1, umpire2 = [], [], [], [], [], [], [], []

for file in files:
    if '.json' in file:
        match = open('Matches New\\' + str(file))        
        data = json.load(match)
        match_id.append(match.name.split('\\')[-1].split('.')[0])
        try:
            city.append(data['info']['city'])
        except:
            city.append(np.nan)
        date.append(data['info']['dates'][0])
        try:
            player_of_match.append(data['info']['player_of_match'][0])
        except:
            player_of_match.append(np.nan)
        venue.append(data['info']['venue'])
        team1.append(data['info']['teams'][0])
        team2.append(data['info']['teams'][1])
        try:
            toss_winner.append(data['info']['toss']['winner'])
        except:
            toss_winner.append(np.nan)
        try:
            toss_decision.append(data['info']['toss']['decision'])
        except:
            toss_decision.append(np.nan)
        try:
            winner.append(data['info']['outcome']['winner'])
        except:
            winner.append(np.nan)
        try:
            result.append([key for key in data['info']['outcome']['by'].items()][0][0])
        except:
            result.append(np.nan)
        try:
            result_margin.append(data['info']['outcome']['by']['runs'])
        except:
            try:
                result_margin.append(data['info']['outcome']['by']['wickets'])
            except:
                result_margin.append(np.nan)
        try:
            method.append(data['info']['outcome']['method'])
        except:
            method.append(np.nan)
        match.close()
        players_list = data['info']['players'][data['info']['teams'][0]] + data['info']['players'][data['info']['teams'][1]]
        players_list = ', '.join(players_list)
        players.append(players_list)
        umpire1.append(data['info']['officials']['umpires'][0])
        umpire2.append(data['info']['officials']['umpires'][1])        
df = pd.DataFrame({'match_id' : match_id, 'city' : city, 'date' : date, 'player_of_match' : player_of_match, 'venue' : venue, 
                   'team1' : team1, 'team2' : team2, 'toss_winner' : toss_winner, 'toss_decision' : toss_decision, 
                   'winner' : winner, 'result' : result, 'result_margin' : result_margin, 'method' : method, 
                   'players' : players, 'umpire1' : umpire1, 'umpire2' : umpire2})
df['match_id'] = df['match_id'].astype('int64')
df['date'] = pd.to_datetime(df['date'])
df = pd.concat([df, missed_matches], axis = 0)
df['year'] = pd.DatetimeIndex(df['date']).year
df.sort_values(by = 'match_id', ascending = True, inplace = True)
df = df[['match_id', 'year', 'city', 'date', 'player_of_match', 'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result', 
         'result_margin', 'method', 'players', 'umpire1', 'umpire2']]
df.reset_index(inplace = True, drop = True)
matches = pd.DataFrame()
for yr in df.year.unique():
    tdf = df[df['year'] == yr]
    tdf['playoff'] = 0
    tdf['knockout'] = 0
    tdf['final'] = 0
    if yr != 2022:
        if yr <= 2009:
            tdf['playoff'][tdf.index.max()] = 1
            tdf['playoff'][tdf.index.max() - 1] = 1
            tdf['playoff'][tdf.index.max() - 2] = 1
        else:
            tdf['playoff'][tdf.index.max()] = 1
            tdf['playoff'][tdf.index.max() - 1] = 1
            tdf['playoff'][tdf.index.max() - 2] = 1
            tdf['playoff'][tdf.index.max() - 3] = 1
        if yr == 2010:
            tdf['knockout'][tdf.index.max()] = 1
            tdf['knockout'][tdf.index.max() - 1] = 1
            tdf['knockout'][tdf.index.max() - 2] = 1
            tdf['knockout'][tdf.index.max() - 3] = 1
        else:
            tdf['knockout'][tdf.index.max()] = 1
            tdf['knockout'][tdf.index.max() - 1] = 1
            tdf['knockout'][tdf.index.max() - 2] = 1
        tdf['final'][tdf.index.max()] = 1
        matches = pd.concat([matches, tdf], axis = 0)
    else:
        matches = pd.concat([matches, tdf], axis = 0)
print('Matches created.')

match_id, innings, overs, balls, batsman, non_striker, bowler, batsman_runs = [], [], [], [], [], [], [], []
extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder_1, fielder_2 = [], [], [], [], [], [], [], []
fielder_3, extras_type_1, extras_type_2, batting_team, bowling_team, target_overs, target_runs = [], [], [], [], [], [], []

for file in files:
    if '.json' in file:
        match = open('Matches New\\' + str(file))
        
        data = json.load(match)
        for inn in range(2):
            for ov in range(20):
                for ball in range(10):                      
                    match_id.append(match.name.split('\\')[-1].split('.')[0])
                    innings.append(inn + 1)
                    overs.append(ov)
                    balls.append(ball + 1)
                    try:
                        batsman.append(data['innings'][inn]['overs'][ov]['deliveries'][ball]['batter'])
                    except:
                        batsman.append(np.nan)
                    try:
                        non_striker.append(data['innings'][inn]['overs'][ov]['deliveries'][ball]['non_striker'])
                    except:
                        non_striker.append(np.nan)
                    try:
                        bowler.append(data['innings'][inn]['overs'][ov]['deliveries'][ball]['bowler'])
                    except:
                        bowler.append(np.nan)
                    try:
                        batsman_runs.append(data['innings'][inn]['overs'][ov]['deliveries'][ball]['runs']['batter'])
                    except:
                        batsman_runs.append(np.nan)
                    try:
                        extra_runs.append(data['innings'][inn]['overs'][ov]['deliveries'][ball]['runs']['extras'])
                    except:
                        extra_runs.append(np.nan)
                    try:
                        total_runs.append(data['innings'][inn]['overs'][ov]['deliveries'][ball]['runs']['total'])
                    except:
                        total_runs.append(np.nan)
                    try:
                        non_boundary.append(data['innings'][inn]['overs'][ov]['deliveries'][ball]['runs']['non_boundary'])
                    except:
                        non_boundary.append(np.nan)
                    try:
                        dismissal_kind.append(data['innings'][inn]['overs'][ov]['deliveries'][ball]['wickets'][0]['kind'])
                    except:
                        dismissal_kind.append('')
                    try:
                        player_dismissed.append(data['innings'][inn]['overs'][ov]['deliveries'][ball]['wickets'][0]['player_out'])
                    except:
                        player_dismissed.append(np.nan)
                    try:
                        fielder_1.append(data['innings'][inn]['overs'][ov]['deliveries'][ball]['wickets'][0]['fielders'][0]['name'])
                    except:
                        fielder_1.append('')
                    try:
                        fielder_2.append(data['innings'][inn]['overs'][ov]['deliveries'][ball]['wickets'][0]['fielders'][1]['name'])
                    except:
                        fielder_2.append('')
                    try:
                        fielder_3.append(data['innings'][inn]['overs'][ov]['deliveries'][ball]['wickets'][0]['fielders'][2]['name'])
                    except:
                        fielder_3.append('')
                    try:
                        extras_type_1.append(
                            [key for key in data['innings'][inn]['overs'][ov]['deliveries'][ball]['extras'].items()][0][0])
                    except:
                        extras_type_1.append('')
                    try:
                        extras_type_2.append(
                            [key for key in data['innings'][inn]['overs'][ov]['deliveries'][ball]['extras'].items()][1][0])
                    except:
                        extras_type_2.append('')
                    try:
                        batting_team.append(data['innings'][inn]['team'])
                    except:
                        batting_team.append(np.nan)
                    try:
                        bowling_team.append([team for team in data['info']['teams'] if team != data['innings'][inn]['team']][0])
                    except:
                        bowling_team.append(np.nan)
                    try:
                        target_overs.append(data['innings'][inn]['target']['overs'])
                    except:
                        target_overs.append(np.nan)
                    try:
                        target_runs.append(data['innings'][inn]['target']['runs'])
                    except:
                        target_runs.append(np.nan)        
        match.close()
details = pd.DataFrame({'match_id' : match_id, 'innings' : innings, 'overs' : overs, 'balls' : balls, 'batsman' : batsman, 
                   'non_striker' : non_striker, 'bowler' : bowler, 'batsman_runs' : batsman_runs, 'extra_runs' : extra_runs, 
                   'total_runs' : total_runs, 'non_boundary' : non_boundary, 'dismissal_kind' : dismissal_kind, 
                   'player_dismissed' : player_dismissed, 'fielder1' : fielder_1, 'fielder2' : fielder_2, 'fielder3' : fielder_3, 
                   'extras_type1' : extras_type_1, 'extras_type2' : extras_type_2, 'batting_team' : batting_team, 
                   'bowling_team' : bowling_team, 'target_overs' : target_overs, 'target_runs' : target_runs})
details = details[details['batsman'].isna() == False]
details.reset_index(inplace = True, drop = True)
fielder, fielder_temp = [], []
for i in details.index:
    fielder_list = []
    for col in ['fielder1', 'fielder2', 'fielder3']:
        if details[col][i] != '':
            fielder_list.append(details[col][i])
    fielder_temp.append(', '.join(fielder_list))
for i in fielder_temp:
    if i != '':
        fielder.append(i)
    else:
        fielder.append(np.nan)
details['fielder'] = fielder
details.drop(['fielder1', 'fielder2', 'fielder3'], axis = 1, inplace = True)
extras_type, extras_type_temp = [], []
for i in details.index:
    extras_list = []
    for col in ['extras_type1', 'extras_type2']:
        if details[col][i] != '':
            extras_list.append(details[col][i])
    extras_type_temp.append(', '.join(extras_list))
for i in extras_type_temp:
    if i != '':
        extras_type.append(i)
    else:
        extras_type.append(np.nan)
details['extras_type'] = extras_type
details.drop(['extras_type1', 'extras_type2'], axis = 1, inplace = True)
for i in details.index:
    if details['dismissal_kind'][i] != '':
        is_wicket.append(1)
    else:
        is_wicket.append(0)
details['is_wicket'] = is_wicket
dk = []
for i in details.index:
    if details['dismissal_kind'][i] != '':
        dk.append(details['dismissal_kind'][i])
    else:
        dk.append(np.nan)
details['dismissal_kind'] = dk
nb = []
for i in details.index:
    if details['non_boundary'][i] == 'True':
        nb.append(1)
    else:
        nb.append(0)
details['non_boundary'] = nb 
details['match_id'] = details['match_id'].astype('int64')
details = details[['match_id', 'innings', 'overs', 'balls', 'batsman', 'non_striker', 'bowler', 'batsman_runs', 'extra_runs', 'total_runs', 
         'non_boundary', 'is_wicket', 'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type', 'batting_team', 'bowling_team', 
         'target_overs', 'target_runs']]
print('Match Details created.')

ipl = details.merge(matches, on = 'match_id', how = 'left')
ipl['date'] = ipl['date'].astype(str)
ipl['year'] = ipl['date'].apply(lambda dateString : datetime.strptime(dateString,'%Y-%m-%d').year)
ipl['date'] = pd.to_datetime(ipl['date'])
ipl = ipl.sort_values(by = ['match_id', 'innings', 'overs', 'balls'])
ipl.reset_index(inplace = True, drop = True)
print('IPL dataset formed.')

final_score = pd.DataFrame(ipl.groupby(['match_id', 'innings'])['total_runs'].sum())
final_score.reset_index(inplace = True)
final_score.rename(columns = {'total_runs' : 'final_score'}, inplace = True)
ipl = ipl.merge(final_score, on = ['match_id', 'innings'], how = 'left')
print('final_score column completed.')

total_wickets = pd.DataFrame(ipl.groupby(['match_id', 'innings'])['is_wicket'].sum())
total_wickets.reset_index(inplace = True)
total_wickets.rename(columns = {'is_wicket' : 'total_wickets'}, inplace = True)
ipl = ipl.merge(total_wickets, on = ['match_id', 'innings'], how = 'left')
print('total_wickets column completed.')

ipl['runs'] = 0
ipl['runs'][0] = ipl['total_runs'][0]
ipl['runs'][ipl.shape[0]-1] = ipl['final_score'][ipl.shape[0]-1]
for i in range(1, ipl.shape[0]-1):
    if ipl['match_id'][i] == ipl['match_id'][i+1]:
        if ipl['innings'][i] == ipl['innings'][i+1]:
            ipl['runs'][i] = ipl['total_runs'][i] + ipl['runs'][i-1]
for i in range(1, ipl.shape[0]-1):
    if ipl['match_id'][i] != ipl['match_id'][i+1]:
        ipl['runs'][i] = ipl['total_runs'][i] + ipl['runs'][i-1]
for i in range(1, ipl.shape[0]-1):
    if ipl['match_id'][i] == ipl['match_id'][i+1]:
        if ipl['innings'][i] != ipl['innings'][i+1]:
            ipl['runs'][i] = ipl['total_runs'][i] + ipl['runs'][i-1]
print('runs column completed.')
            
ipl['wickets'] = 0
ipl['wickets'][0] = ipl['is_wicket'][0]
ipl['wickets'][ipl.shape[0]-1] = ipl['total_wickets'][ipl.shape[0]-1]
for i in range(1, ipl.shape[0]-1):
    if ipl['match_id'][i] == ipl['match_id'][i+1]:
        if ipl['innings'][i] == ipl['innings'][i+1]:
            ipl['wickets'][i] = ipl['is_wicket'][i] + ipl['wickets'][i-1]
for i in range(ipl.shape[0]-1):
    if ipl['match_id'][i] != ipl['match_id'][i+1]:
        ipl['wickets'][i] = ipl['total_wickets'][i]
for i in range(ipl.shape[0]-1):
    if ipl['match_id'][i] == ipl['match_id'][i+1]:
        if ipl['innings'][i] != ipl['innings'][i+1]:
            ipl['wickets'][i] = ipl['total_wickets'][i]
print('wickets column completed.')
            
ipl['runs_last_5_overs'] = 0
for i in ipl.index:
    if ipl['overs'][i] <= 4:
        ipl['runs_last_5_overs'][i] = ipl['runs'][i]
for i in ipl.index:
    if ipl['overs'][i] > 4:
        if ipl['match_id'][i] == ipl['match_id'][i-30]:
            if ipl['innings'][i] == ipl['innings'][i-30]:
                ipl['runs_last_5_overs'][i] = ipl['runs'][i] - ipl['runs'][i-30]
print('runs_last_5_overs column completed.')
                
ipl['wickets_last_5_overs'] = 0
for i in ipl.index:
    if ipl['overs'][i] <= 4:
        ipl['wickets_last_5_overs'][i] = ipl['wickets'][i]
for i in ipl.index:
    if ipl['overs'][i] > 4:
        if ipl['match_id'][i] == ipl['match_id'][i-30]:
            if ipl['innings'][i] == ipl['innings'][i-30]:
                ipl['wickets_last_5_overs'][i] = ipl['wickets'][i] - ipl['wickets'][i-30]
for i in ipl.index:
    if ipl['overs'][i] > 4:
        if ipl['match_id'][i] != ipl['match_id'][i-1]:
            ipl['wickets_last_5_overs'][i-1] = ipl['wickets'][i-1] - ipl['wickets'][i-31]
for i in ipl.index:
    if ipl['overs'][i] > 4:
        if ipl['match_id'][i] == ipl['match_id'][i-1]:
            if ipl['innings'][i] != ipl['innings'][i-1]:
                ipl['wickets_last_5_overs'][i-1] = ipl['wickets'][i-1] - ipl['wickets'][i-31]
print('wickets_last_5_overs column completed.')

ipl['ball_no'] = 0
ipl['extras_type'] = ipl['extras_type'].astype(str)
for i in ipl.index:
    if (ipl['overs'][i] == 0) & (ipl['balls'][i] == 1):
        ipl['ball_no'][i] = 1
for i in range(1, ipl.shape[0]):
    if (ipl['overs'][i] == 0) & (ipl['balls'][i] == 1):
        pass
    else:
        if 'wides' in ipl['extras_type'][i-1]:
            ipl['ball_no'][i] = ipl['ball_no'][i-1]
        elif 'noballs' in ipl['extras_type'][i-1]:
            ipl['ball_no'][i] = ipl['ball_no'][i-1]
        else:
            ipl['ball_no'][i] = ipl['ball_no'][i-1] + 1
print('ball number completed.')

ipl['balls'] = ipl['ball_no'] % 6
print('balls completed.')

for i in ipl.index:
    if ipl['balls'][i] == 0:
        ipl['overs'][i] += 1
print('overs completed.')

max_balls = pd.DataFrame(ipl.groupby(['match_id', 'innings'])['ball_no'].max())
max_balls.rename(columns = {'ball_no' : 'max_balls'}, inplace = True)
max_balls.reset_index(inplace = True)
ipl = ipl.merge(max_balls, on = ['match_id', 'innings'], how = 'left')
ipl['balls_remaining'] = 0
for i in ipl.index:
    if ipl['innings'][i] == 1:
        ipl['balls_remaining'][i] = ipl['max_balls'][i] - ipl['ball_no'][i]
    else:
        ipl['balls_remaining'][i] = (ipl['target_overs'][i] * 6) - ipl['ball_no'][i]
print('balls remaining completed.')

ipl['runs_scored_in_remaining_balls'] = 0
ipl['runs_required'] = 0
for i in ipl.index:
    if ipl['innings'][i] == 1:
        ipl['runs_scored_in_remaining_balls'][i] = ipl['final_score'][i] - ipl['runs'][i]
    else:
        ipl['runs_required'][i] = ipl['target_runs'][i] - ipl['runs'][i]
print('runs scored/required completed.')

won = []
for i in ipl.index:
    if ipl['batting_team'][i] == ipl['winner'][i]:
        won.append(1)
    else:
        won.append(0)
ipl['won'] = won
print('won column created.')

for col in ['team1', 'team2', 'batting_team', 'bowling_team']:
    t_list = []
    for i in ipl[col]:
        if i == 'Delhi Daredevils':
            t_list.append('Delhi Capitals')
        elif i == 'Rising Pune Supergiants':
            t_list.append('Rising Pune Supergiant')
        elif i == 'Kings XI Punjab':
            t_list.append('Punjab Kings')
        else:
            t_list.append(i)
    ipl[col] = t_list
print(col + ' cleaned.')

t_list = []
for i in ipl['venue']:
    if i == 'M.Chinnaswamy Stadium':
        t_list.append('M Chinnaswamy Stadium')
    elif i == 'MA Chidambaram Stadium, Chepauk, Chennai':
        t_list.append('MA Chidambaram Stadium')
    elif i == 'MA Chidambaram Stadium, Chepauk':
        t_list.append('MA Chidambaram Stadium')
    elif i == 'Subrata Roy Sahara Stadium':
        t_list.append('Maharashtra Cricket Association Stadium')
    elif i == 'Sardar Patel Stadium, Motera':
        t_list.append('Narendra Modi Stadium')
    elif i == 'Narendra Modi Stadium, Ahmedabad':
        t_list.append('Narendra Modi Stadium')
    elif i == 'Wankhede Stadium, Mumbai':
        t_list.append('Wankhede Stadium')
    elif i == 'Feroz Shah Kotla':
        t_list.append('Arun Jaitley Stadium')
    elif i == 'Arun Jaitley Stadium, Delhi':
        t_list.append('Arun Jaitley Stadium')
    elif i == 'Brabourne Stadium, Mumbai':
        t_list.append('Brabourne Stadium')
    elif i == 'Punjab Cricket Association IS Bindra Stadium, Mohali':
        t_list.append('Punjab Cricket Association IS Bindra Stadium')
    elif i == 'Punjab Cricket Association Stadium, Mohali':
        t_list.append('Punjab Cricket Association IS Bindra Stadium')
    elif i == 'Rajiv Gandhi International Stadium, Uppal':
        t_list.append('Rajiv Gandhi International Stadium')
    elif i == 'Zayed Cricket Stadium, Abu Dhabi':
        t_list.append('Sheikh Zayed Stadium')
    elif i == 'Vidarbha Cricket Association Stadium, Jamtha':
        t_list.append('Vidarbha Cricket Association Stadium')
    else:
        t_list.append(i)
ipl['venue'] = t_list
print('venue cleaned.')

ipl = ipl[['match_id', 'year', 'date', 'city', 'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'innings', 'batting_team', 
           'bowling_team', 'batsman', 'non_striker', 'bowler', 'overs', 'balls', 'batsman_runs', 'extra_runs', 'total_runs', 
           'non_boundary', 'is_wicket', 'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type', 'runs', 'wickets', 'runs_last_5_overs', 
           'wickets_last_5_overs', 'target_overs', 'target_runs', 'balls_remaining', 'runs_scored_in_remaining_balls', 'runs_required', 
           'winner', 'result', 'result_margin', 'player_of_match', 'playoff', 'knockout', 'final', 'method', 'players', 'umpire1', 'umpire2', 
           'final_score', 'total_wickets']]
ipl_1 = ipl[ipl['innings'] == 1]
ipl_2 = ipl[ipl['innings'] == 2]

matches = matches.merge(ipl_1[['match_id', 'final_score', 'total_wickets']], on = 'match_id', how = 'left')
matches.drop_duplicates(inplace = True)
matches.rename(columns = {'final_score' : 'innings_1_score', 'total_wickets' : 'innings_1_wickets'}, inplace = True)
matches = matches.merge(ipl_2[['match_id', 'final_score', 'total_wickets']], on = 'match_id', how = 'left')
matches.drop_duplicates(inplace = True)
matches.rename(columns = {'final_score' : 'innings_2_score', 'total_wickets' : 'innings_2_wickets'}, inplace = True)
print('Scores and wickets added to matches.')

innings_1_bat_team, innings_2_bat_team = [], []
for i in matches.index:
    if (matches['team1'][i] == matches['toss_winner'][i]) and (matches['toss_decision'][i] == 'bat'):
        innings_1_bat_team.append(matches['team1'][i])
        innings_2_bat_team.append(matches['team2'][i])
    elif (matches['team1'][i] == matches['toss_winner'][i]) and (matches['toss_decision'][i] == 'field'):
        innings_1_bat_team.append(matches['team2'][i])
        innings_2_bat_team.append(matches['team1'][i])
    elif (matches['team2'][i] == matches['toss_winner'][i]) and (matches['toss_decision'][i] == 'bat'):
        innings_1_bat_team.append(matches['team2'][i])
        innings_2_bat_team.append(matches['team1'][i])
    elif (matches['team2'][i] == matches['toss_winner'][i]) and (matches['toss_decision'][i] == 'field'):
        innings_1_bat_team.append(matches['team1'][i])
        innings_2_bat_team.append(matches['team2'][i])
    else:
        innings_1_bat_team.append(np.nan)
        innings_2_bat_team.append(np.nan)
matches['innings_1_bat_team'] = innings_1_bat_team
matches['innings_2_bat_team'] = innings_2_bat_team
print('Batting and bowling teams added to matches.')

matches.to_sql(name = 'match_list', con = engine, if_exists = 'append', chunksize = 1500, index = None)
ipl.to_sql(name = 'match_details', con = engine, if_exists = 'append', chunksize = 5000, index = None)
print('Data pushed to DB.')

for file in new:
    os.replace('Matches New\\' + file, 'Matches\\' + file)
print('Files moved to Matches folder.')
# Out:
# <style>.container{width : 100% ! important;}</style>
# Data downloaded.
# Data extracted.
# Files moved to Matches New folder.
# Matches created.
# Match Details created.
# IPL dataset formed.
# final_score column completed.
# total_wickets column completed.
# runs column completed.
# wickets column completed.
# runs_last_5_overs column completed.
# wickets_last_5_overs column completed.
# ball number completed.
# balls completed.
# overs completed.
# balls remaining completed.
# runs scored/required completed.
# won column created.
# bowling_team cleaned.
# venue cleaned.
# 2022-04-07 21:34:44,326 INFO sqlalchemy.engine.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2022-04-07 21:34:44,326 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-04-07 21:34:44,415 INFO sqlalchemy.engine.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2022-04-07 21:34:44,415 INFO sqlalchemy.engine.Engine [generated in 0.02999s] {}
# 2022-04-07 21:34:44,631 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-04-07 21:34:44,631 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-04-07 21:34:44,935 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-04-07 21:34:44,935 INFO sqlalchemy.engine.Engine [generated in 0.08711s] {'table_schema': 'ipl', 'table_name': 'match_list'}
# 2022-04-07 21:34:45,018 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-07 21:34:45,081 INFO sqlalchemy.engine.Engine
# CREATE TABLE match_list (
# 	match_id BIGINT,
# 	year BIGINT,
# 	city TEXT,
# 	date DATETIME,
# 	player_of_match TEXT,
# 	venue TEXT,
# 	team1 TEXT,
# 	team2 TEXT,
# 	toss_winner TEXT,
# 	toss_decision TEXT,
# 	winner TEXT,
# 	result TEXT,
# 	result_margin FLOAT(53),
# 	method TEXT,
# 	players TEXT,
# 	umpire1 TEXT,
# 	umpire2 TEXT,
# 	playoff BIGINT,
# 	knockout BIGINT,
# 	final BIGINT
# )
#
#
# 2022-04-07 21:34:45,081 INFO sqlalchemy.engine.Engine [no key 0.05295s] {}
# 2022-04-07 21:34:45,183 INFO sqlalchemy.engine.Engine COMMIT
# 2022-04-07 21:34:45,335 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-07 21:34:45,398 INFO sqlalchemy.engine.Engine INSERT INTO match_list (match_id, year, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, method, players, umpire1, umpire2, playoff, knockout, final) VALUES (%(match_id)s, %(year)s, %(city)s, %(date)s, %(player_of_match)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(winner)s, %(result)s, %(result_margin)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(playoff)s, %(knockout)s, %(final)s)
# 2022-04-07 21:34:45,398 INFO sqlalchemy.engine.Engine [generated in 0.05266s] ({'match_id': 335982, 'year': 2008, 'city': 'Bangalore', 'date': datetime.datetime(2008, 4, 18, 0, 0), 'player_of_match': 'BB McCullum', 'venue': 'M Chinnaswamy Stadium', 'team1': 'Royal Challengers Bangalore', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Royal Challengers Bangalore', 'toss_decision': 'field', 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 140.0, 'method': None, 'players': 'R Dravid, W Jaffer, V Kohli, JH Kallis, CL White, MV Boucher, B Akhil, AA Noffke, P Kumar, Z Khan, SB Joshi, SC Ganguly, BB McCullum, RT Ponting, DJ Hussey, Mohammad Hafeez, LR Shukla, WP Saha, AB Agarkar, AB Dinda, M Kartik, I Sharma', 'umpire1': 'Asad Rauf', 'umpire2': 'RE Koertzen', 'playoff': 0, 'knockout': 0, 'final': 0}, {'match_id': 335983, 'year': 2008, 'city': 'Chandigarh', 'date': datetime.datetime(2008, 4, 19, 0, 0), 'player_of_match': 'MEK Hussey', 'venue': 'Punjab Cricket Association Stadium, Mohali', 'team1': 'Kings XI Punjab', 'team2': 'Chennai Super Kings', 'toss_winner': 'Chennai Super Kings', 'toss_decision': 'bat', 'winner': 'Chennai Super Kings', 'result': 'runs', 'result_margin': 33.0, 'method': None, 'players': 'K Goel, JR Hopes, KC Sangakkara, Yuvraj Singh, SM Katich, IK Pathan, P Dharmani, B Lee, PP Chawla, WA Mota, S Sreesanth, PA Patel, ML Hayden, MEK Hussey, MS Dhoni, SK Raina, JDP Oram, S Badrinath, Joginder Sharma, P Amarnath, MS Gony, M Muralitharan', 'umpire1': 'MR Benson', 'umpire2': 'SL Shastri', 'playoff': 0, 'knockout': 0, 'final': 0}, {'match_id': 335984, 'year': 2008, 'city': 'Delhi', 'date': datetime.datetime(2008, 4, 19, 0, 0), 'player_of_match': 'MF Maharoof', 'venue': 'Feroz Shah Kotla', 'team1': 'Delhi Daredevils', 'team2': 'Rajasthan Royals', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'bat', 'winner': 'Delhi Daredevils', 'result': 'wickets', 'result_margin': 9.0, 'method': None, 'players': 'G Gambhir, V Sehwag, S Dhawan, MK Tiwary, KD Karthik, R Bhatia, M Manhas, DL Vettori, MF Maharoof, B Geeves, GD McGrath, T Kohli, YK Pathan, SR Watson, M Kaif, DS Lehmann, RA Jadeja, M Rawat, D Salunkhe, SK Warne, SK Trivedi, MM Patel', 'umpire1': 'Aleem Dar', 'umpire2': 'GA Pratapkumar', 'playoff': 0, 'knockout': 0, 'final': 0}, {'match_id': 335985, 'year': 2008, 'city': 'Mumbai', 'date': datetime.datetime(2008, 4, 20, 0, 0), 'player_of_match': 'MV Boucher', 'venue': 'Wankhede Stadium', 'team1': 'Mumbai Indians', 'team2': 'Royal Challengers Bangalore', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'bat', 'winner': 'Royal Challengers Bangalore', 'result': 'wickets', 'result_margin': 5.0, 'method': None, 'players': 'L Ronchi, ST Jayasuriya, DJ Thornely, RV Uthappa, PR Shah, AM Nayar, SM Pollock, Harbhajan Singh, MA Khote, A Nehra, DS Kulkarni, S Chanderpaul, R Dravid, LRPL Taylor, JH Kallis, V Kohli, MV Boucher, B Akhil, P Kumar, Z Khan, SB Joshi, R Vinay Kumar', 'umpire1': 'SJ Davis', 'umpire2': 'DJ Harper', 'playoff': 0, 'knockout': 0, 'final': 0}, {'match_id': 335986, 'year': 2008, 'city': 'Kolkata', 'date': datetime.datetime(2008, 4, 20, 0, 0), 'player_of_match': 'DJ Hussey', 'venue': 'Eden Gardens', 'team1': 'Kolkata Knight Riders', 'team2': 'Deccan Chargers', 'toss_winner': 'Deccan Chargers', 'toss_decision': 'bat', 'winner': 'Kolkata Knight Riders', 'result': 'wickets', 'result_margin': 5.0, 'method': None, 'players': 'WP Saha, BB McCullum, RT Ponting, SC Ganguly, DJ Hussey, Mohammad Hafeez, LR Shukla, AB Agarkar, AB Dinda, M Kartik, I Sharma, AC Gilchrist, Y Venugopal Rao, VVS Laxman, A Symonds, RG Sharma, SB Styris, AS Yadav, SB Bangar, WPUJC Vaas, RP Singh, PP Ojha', 'umpire1': 'BF Bowden', 'umpire2': 'K Hariharan', 'playoff': 0, 'knockout': 0, 'final': 0}, {'match_id': 335987, 'year': 2008, 'city': 'Jaipur', 'date': datetime.datetime(2008, 4, 21, 0, 0), 'player_of_match': 'SR Watson', 'venue': 'Sawai Mansingh Stadium', 'team1': 'Rajasthan Royals', 'team2': 'Kings XI Punjab', 'toss_winn ...
# 2022-04-07 21:34:46,670 INFO sqlalchemy.engine.Engine COMMIT
# 2022-04-07 21:34:47,375 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-04-07 21:34:47,375 INFO sqlalchemy.engine.Engine [cached since 2.521s ago] {'table_schema': 'ipl', 'table_name': 'match_details'}
# 2022-04-07 21:34:47,484 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-07 21:34:47,562 INFO sqlalchemy.engine.Engine
# CREATE TABLE match_details (
# 	match_id BIGINT,
# 	innings BIGINT,
# 	overs BIGINT,
# 	balls BIGINT,
# 	batsman TEXT,
# 	non_striker TEXT,
# 	bowler TEXT,
# 	batsman_runs FLOAT(53),
# 	extra_runs FLOAT(53),
# 	total_runs FLOAT(53),
# 	non_boundary BIGINT,
# 	is_wicket BIGINT,
# 	dismissal_kind TEXT,
# 	player_dismissed TEXT,
# 	fielder TEXT,
# 	extras_type TEXT,
# 	batting_team TEXT,
# 	bowling_team TEXT,
# 	target_overs FLOAT(53),
# 	target_runs FLOAT(53),
# 	year BIGINT,
# 	city TEXT,
# 	date DATETIME,
# 	player_of_match TEXT,
# 	venue TEXT,
# 	team1 TEXT,
# 	team2 TEXT,
# 	toss_winner TEXT,
# 	toss_decision TEXT,
# 	winner TEXT,
# 	result TEXT,
# 	result_margin FLOAT(53),
# 	method TEXT,
# 	players TEXT,
# 	umpire1 TEXT,
# 	umpire2 TEXT,
# 	playoff BIGINT,
# 	knockout BIGINT,
# 	final BIGINT,
# 	final_score FLOAT(53),
# 	total_wickets BIGINT,
# 	runs BIGINT,
# 	wickets BIGINT,
# 	runs_last_5_overs BIGINT,
# 	wickets_last_5_overs BIGINT,
# 	ball_no BIGINT,
# 	max_balls BIGINT,
# 	balls_remaining BIGINT,
# 	runs_scored_in_remaining_balls BIGINT,
# 	runs_required BIGINT,
# 	won BIGINT
# )
#
#
# 2022-04-07 21:34:47,577 INFO sqlalchemy.engine.Engine [no key 0.07058s] {}
# 2022-04-07 21:34:47,684 INFO sqlalchemy.engine.Engine COMMIT
# 2022-04-07 21:34:48,427 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-07 21:34:48,722 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, innings, overs, balls, batsman, non_striker, bowler, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, batting_team, bowling_team, target_overs, target_runs, year, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, method, players, umpire1, umpire2, playoff, knockout, final, final_score, total_wickets, runs, wickets, runs_last_5_overs, wickets_last_5_overs, ball_no, max_balls, balls_remaining, runs_scored_in_remaining_balls, runs_required, won) VALUES (%(match_id)s, %(innings)s, %(overs)s, %(balls)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(batting_team)s, %(bowling_team)s, %(target_overs)s, %(target_runs)s, %(year)s, %(city)s, %(date)s, %(player_of_match)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(winner)s, %(result)s, %(result_margin)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(playoff)s, %(knockout)s, %(final)s, %(final_score)s, %(total_wickets)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(ball_no)s, %(max_balls)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(won)s)
# 2022-04-07 21:34:48,722 INFO sqlalchemy.engine.Engine [generated in 0.26653s] ({'match_id': 335982, 'innings': 1, 'overs': 0, 'balls': 1, 'batsman': 'SC Ganguly', 'non_striker': 'BB McCullum', 'bowler': 'P Kumar', 'batsman_runs': 0.0, 'extra_runs': 1.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'legbyes', 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Royal Challengers Bangalore', 'target_overs': None, 'target_runs': None, 'year': 2008, 'city': 'Bangalore', 'date': datetime.datetime(2008, 4, 18, 0, 0), 'player_of_match': 'BB McCullum', 'venue': 'M Chinnaswamy Stadium', 'team1': 'Royal Challengers Bangalore', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Royal Challengers Bangalore', 'toss_decision': 'field', 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 140.0, 'method': None, 'players': 'R Dravid, W Jaffer, V Kohli, JH Kallis, CL White, MV Boucher, B Akhil, AA Noffke, P Kumar, Z Khan, SB Joshi, SC Ganguly, BB McCullum, RT Ponting, DJ Hussey, Mohammad Hafeez, LR Shukla, WP Saha, AB Agarkar, AB Dinda, M Kartik, I Sharma', 'umpire1': 'Asad Rauf', 'umpire2': 'RE Koertzen', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 222.0, 'total_wickets': 3, 'runs': 1, 'wickets': 0, 'runs_last_5_overs': 1, 'wickets_last_5_overs': 0, 'ball_no': 1, 'max_balls': 120, 'balls_remaining': 119, 'runs_scored_in_remaining_balls': 221, 'runs_required': 0, 'won': 1}, {'match_id': 335982, 'innings': 1, 'overs': 0, 'balls': 2, 'batsman': 'BB McCullum', 'non_striker': 'SC Ganguly', 'bowler': 'P Kumar', 'batsman_runs': 0.0, 'extra_runs': 0.0, 'total_runs': 0.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Royal Challengers Bangalore', 'target_overs': None, 'target_runs': None, 'year': 2008, 'city': 'Bangalore', 'date': datetime.datetime(2008, 4, 18, 0, 0), 'player_of_match': 'BB McCullum', 'venue': 'M Chinnaswamy Stadium', 'team1': 'Royal Challengers Bangalore', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Royal Challengers Bangalore', 'toss_decision': 'field', 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 140.0, 'method': None, 'players': 'R Dravid, W Jaffer, V Kohli, JH Kallis, CL White, MV Boucher, B Akhil, AA Noffke, P Kumar, Z Khan, SB Joshi, SC Ganguly, BB McCullum, RT Ponting, DJ Hussey, Mohammad Hafeez, LR Shukla, WP Saha, AB Agarkar, AB Dinda, M Kartik, I Sharma', 'umpire1': 'Asad Rauf', 'umpire2': 'RE Koertzen', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 222.0, 'total_wickets': 3, 'runs': 1, 'wickets': 0, 'runs_last_5_overs': 1, 'wickets_last_5_overs': 0, 'ball_no': 2, 'max_balls': 120, 'balls_remaining': 118, 'runs_scored_in_remaining_balls': 221, 'runs_required': 0, 'won': 1}, {'match_id': 335982, 'innings': 1, 'overs': 0, 'balls': 3, 'batsman': 'BB McCullum', 'non_striker': 'SC Ganguly', 'bowler': 'P Kumar', 'batsman_runs': 0.0, 'extra_runs': 1.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'wides', 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Royal Challengers Bangalore', 'target_overs': None, 'target_runs': None, 'year': 2008, 'city': 'Bangalore', 'date': datetime.datetime(2008, 4, 18, 0, 0), 'player_of_match': 'BB McCullum', 'venue': 'M Chinnaswamy Stadium', 'team1': 'Royal Challengers Bangalore', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Royal Challengers Bangalore', 'toss_decision': 'field', 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 140.0, 'method': None, 'players': 'R Dravid, W Jaffer, V Kohli, JH Kallis, CL White, MV Boucher, B Akhil, AA Noffke, P Kumar, Z Khan, SB Joshi, SC Ganguly, BB McCullum, RT Ponting, DJ Hussey, Mohammad Hafeez, LR Shukla, WP Saha, AB Agarkar, AB Dinda, M Kartik ...
# 2022-04-07 21:34:56,455 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, innings, overs, balls, batsman, non_striker, bowler, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, batting_team, bowling_team, target_overs, target_runs, year, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, method, players, umpire1, umpire2, playoff, knockout, final, final_score, total_wickets, runs, wickets, runs_last_5_overs, wickets_last_5_overs, ball_no, max_balls, balls_remaining, runs_scored_in_remaining_balls, runs_required, won) VALUES (%(match_id)s, %(innings)s, %(overs)s, %(balls)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(batting_team)s, %(bowling_team)s, %(target_overs)s, %(target_runs)s, %(year)s, %(city)s, %(date)s, %(player_of_match)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(winner)s, %(result)s, %(result_margin)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(playoff)s, %(knockout)s, %(final)s, %(final_score)s, %(total_wickets)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(ball_no)s, %(max_balls)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(won)s)
# 2022-04-07 21:34:56,455 INFO sqlalchemy.engine.Engine [cached since 7.996s ago] ({'match_id': 336003, 'innings': 1, 'overs': 1, 'balls': 1, 'batsman': 'SE Marsh', 'non_striker': 'JR Hopes', 'bowler': 'AB Agarkar', 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Punjab Kings', 'bowling_team': 'Kolkata Knight Riders', 'target_overs': None, 'target_runs': None, 'year': 2008, 'city': 'Chandigarh', 'date': datetime.datetime(2008, 5, 3, 0, 0), 'player_of_match': 'IK Pathan', 'venue': 'Punjab Cricket Association IS Bindra Stadium', 'team1': 'Punjab Kings', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Kings XI Punjab', 'toss_decision': 'bat', 'winner': 'Kings XI Punjab', 'result': 'runs', 'result_margin': 9.0, 'method': None, 'players': 'SE Marsh, JR Hopes, KC Sangakkara, Yuvraj Singh, DPMD Jayawardene, K Goel, IK Pathan, PP Chawla, S Sreesanth, VRV Singh, Gagandeep Singh, Mohammad Hafeez, SC Ganguly, DB Das, BJ Hodge, DJ Hussey, LR Shukla, WP Saha, AB Agarkar, Umar Gul, I Sharma, AB Dinda', 'umpire1': 'DJ Harper', 'umpire2': 'I Shivram', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 178.0, 'total_wickets': 6, 'runs': 6, 'wickets': 0, 'runs_last_5_overs': 6, 'wickets_last_5_overs': 0, 'ball_no': 7, 'max_balls': 120, 'balls_remaining': 113, 'runs_scored_in_remaining_balls': 172, 'runs_required': 0, 'won': 1}, {'match_id': 336003, 'innings': 1, 'overs': 1, 'balls': 2, 'batsman': 'JR Hopes', 'non_striker': 'SE Marsh', 'bowler': 'AB Agarkar', 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Punjab Kings', 'bowling_team': 'Kolkata Knight Riders', 'target_overs': None, 'target_runs': None, 'year': 2008, 'city': 'Chandigarh', 'date': datetime.datetime(2008, 5, 3, 0, 0), 'player_of_match': 'IK Pathan', 'venue': 'Punjab Cricket Association IS Bindra Stadium', 'team1': 'Punjab Kings', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Kings XI Punjab', 'toss_decision': 'bat', 'winner': 'Kings XI Punjab', 'result': 'runs', 'result_margin': 9.0, 'method': None, 'players': 'SE Marsh, JR Hopes, KC Sangakkara, Yuvraj Singh, DPMD Jayawardene, K Goel, IK Pathan, PP Chawla, S Sreesanth, VRV Singh, Gagandeep Singh, Mohammad Hafeez, SC Ganguly, DB Das, BJ Hodge, DJ Hussey, LR Shukla, WP Saha, AB Agarkar, Umar Gul, I Sharma, AB Dinda', 'umpire1': 'DJ Harper', 'umpire2': 'I Shivram', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 178.0, 'total_wickets': 6, 'runs': 10, 'wickets': 0, 'runs_last_5_overs': 10, 'wickets_last_5_overs': 0, 'ball_no': 8, 'max_balls': 120, 'balls_remaining': 112, 'runs_scored_in_remaining_balls': 168, 'runs_required': 0, 'won': 1}, {'match_id': 336003, 'innings': 1, 'overs': 1, 'balls': 3, 'batsman': 'JR Hopes', 'non_striker': 'SE Marsh', 'bowler': 'AB Agarkar', 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Punjab Kings', 'bowling_team': 'Kolkata Knight Riders', 'target_overs': None, 'target_runs': None, 'year': 2008, 'city': 'Chandigarh', 'date': datetime.datetime(2008, 5, 3, 0, 0), 'player_of_match': 'IK Pathan', 'venue': 'Punjab Cricket Association IS Bindra Stadium', 'team1': 'Punjab Kings', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Kings XI Punjab', 'toss_decision': 'bat', 'winner': 'Kings XI Punjab', 'result': 'runs', 'result_margin': 9.0, 'method': None, 'players': 'SE Marsh, JR Hopes, KC Sangakkara, Yuvraj Singh, DPMD Jayawardene, K Goel, IK Pathan, PP Chawla, S Sreesanth, VRV Singh, Gagandeep Singh, Mohammad Hafeez, SC Ganguly, DB Das, BJ Hodge, DJ Hussey, LR Shukla, WP Saha, AB Agarkar, Umar Gul, I Sharma, AB Dinda', 'umpire1': 'DJ Harper', 'u ...
# 2022-04-07 21:35:05,218 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, innings, overs, balls, batsman, non_striker, bowler, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, batting_team, bowling_team, target_overs, target_runs, year, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, method, players, umpire1, umpire2, playoff, knockout, final, final_score, total_wickets, runs, wickets, runs_last_5_overs, wickets_last_5_overs, ball_no, max_balls, balls_remaining, runs_scored_in_remaining_balls, runs_required, won) VALUES (%(match_id)s, %(innings)s, %(overs)s, %(balls)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(batting_team)s, %(bowling_team)s, %(target_overs)s, %(target_runs)s, %(year)s, %(city)s, %(date)s, %(player_of_match)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(winner)s, %(result)s, %(result_margin)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(playoff)s, %(knockout)s, %(final)s, %(final_score)s, %(total_wickets)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(ball_no)s, %(max_balls)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(won)s)
# 2022-04-07 21:35:05,218 INFO sqlalchemy.engine.Engine [cached since 16.76s ago] ({'match_id': 336025, 'innings': 1, 'overs': 10, 'balls': 2, 'batsman': 'Salman Butt', 'non_striker': 'DB Das', 'bowler': 'L Balaji', 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Chennai Super Kings', 'target_overs': None, 'target_runs': None, 'year': 2008, 'city': 'Kolkata', 'date': datetime.datetime(2008, 5, 18, 0, 0), 'player_of_match': 'M Ntini', 'venue': 'Eden Gardens', 'team1': 'Kolkata Knight Riders', 'team2': 'Chennai Super Kings', 'toss_winner': 'Kolkata Knight Riders', 'toss_decision': 'bat', 'winner': 'Chennai Super Kings', 'result': 'runs', 'result_margin': 3.0, 'method': 'D/L', 'players': 'Salman Butt, Mohammad Hafeez, SC Ganguly, DB Das, DJ Hussey, LR Shukla, WP Saha, AB Agarkar, I Sharma, AB Dinda, Shoaib Akhtar, PA Patel, SP Fleming, S Vidyut, SK Raina, S Badrinath, MS Dhoni, JA Morkel, MS Gony, L Balaji, M Muralitharan, M Ntini', 'umpire1': 'Asad Rauf', 'umpire2': 'K Hariharan', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 149.0, 'total_wickets': 5, 'runs': 66, 'wickets': 2, 'runs_last_5_overs': 33, 'wickets_last_5_overs': 0, 'ball_no': 62, 'max_balls': 120, 'balls_remaining': 58, 'runs_scored_in_remaining_balls': 83, 'runs_required': 0, 'won': 0}, {'match_id': 336025, 'innings': 1, 'overs': 10, 'balls': 3, 'batsman': 'Salman Butt', 'non_striker': 'DB Das', 'bowler': 'L Balaji', 'batsman_runs': 0.0, 'extra_runs': 0.0, 'total_runs': 0.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Chennai Super Kings', 'target_overs': None, 'target_runs': None, 'year': 2008, 'city': 'Kolkata', 'date': datetime.datetime(2008, 5, 18, 0, 0), 'player_of_match': 'M Ntini', 'venue': 'Eden Gardens', 'team1': 'Kolkata Knight Riders', 'team2': 'Chennai Super Kings', 'toss_winner': 'Kolkata Knight Riders', 'toss_decision': 'bat', 'winner': 'Chennai Super Kings', 'result': 'runs', 'result_margin': 3.0, 'method': 'D/L', 'players': 'Salman Butt, Mohammad Hafeez, SC Ganguly, DB Das, DJ Hussey, LR Shukla, WP Saha, AB Agarkar, I Sharma, AB Dinda, Shoaib Akhtar, PA Patel, SP Fleming, S Vidyut, SK Raina, S Badrinath, MS Dhoni, JA Morkel, MS Gony, L Balaji, M Muralitharan, M Ntini', 'umpire1': 'Asad Rauf', 'umpire2': 'K Hariharan', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 149.0, 'total_wickets': 5, 'runs': 66, 'wickets': 2, 'runs_last_5_overs': 33, 'wickets_last_5_overs': 0, 'ball_no': 63, 'max_balls': 120, 'balls_remaining': 57, 'runs_scored_in_remaining_balls': 83, 'runs_required': 0, 'won': 0}, {'match_id': 336025, 'innings': 1, 'overs': 10, 'balls': 4, 'batsman': 'Salman Butt', 'non_striker': 'DB Das', 'bowler': 'L Balaji', 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Chennai Super Kings', 'target_overs': None, 'target_runs': None, 'year': 2008, 'city': 'Kolkata', 'date': datetime.datetime(2008, 5, 18, 0, 0), 'player_of_match': 'M Ntini', 'venue': 'Eden Gardens', 'team1': 'Kolkata Knight Riders', 'team2': 'Chennai Super Kings', 'toss_winner': 'Kolkata Knight Riders', 'toss_decision': 'bat', 'winner': 'Chennai Super Kings', 'result': 'runs', 'result_margin': 3.0, 'method': 'D/L', 'players': 'Salman Butt, Mohammad Hafeez, SC Ganguly, DB Das, DJ Hussey, LR Shukla, WP Saha, AB Agarkar, I Sharma, AB Dinda, Shoaib Akhtar, PA Patel, SP Fleming, S Vidyut, SK Raina, S Badrinath, MS Dhoni, JA Morkel, MS Gony, L Balaji, M Muralitharan, M Ntini', 'umpire1': 'Asad Rauf', 'umpire2': 'K Hariharan', 'playoff': 0, 'knockout': 0, 'final ...
# 2022-04-07 21:35:14,055 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, innings, overs, balls, batsman, non_striker, bowler, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, batting_team, bowling_team, target_overs, target_runs, year, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, method, players, umpire1, umpire2, playoff, knockout, final, final_score, total_wickets, runs, wickets, runs_last_5_overs, wickets_last_5_overs, ball_no, max_balls, balls_remaining, runs_scored_in_remaining_balls, runs_required, won) VALUES (%(match_id)s, %(innings)s, %(overs)s, %(balls)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(batting_team)s, %(bowling_team)s, %(target_overs)s, %(target_runs)s, %(year)s, %(city)s, %(date)s, %(player_of_match)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(winner)s, %(result)s, %(result_margin)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(playoff)s, %(knockout)s, %(final)s, %(final_score)s, %(total_wickets)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(ball_no)s, %(max_balls)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(won)s)
# 2022-04-07 21:35:14,055 INFO sqlalchemy.engine.Engine [cached since 25.59s ago] ({'match_id': 392189, 'innings': 1, 'overs': 14, 'balls': 1, 'batsman': 'AB de Villiers', 'non_striker': 'MK Tiwary', 'bowler': 'A Flintoff', 'batsman_runs': 2.0, 'extra_runs': 0.0, 'total_runs': 2.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Delhi Capitals', 'bowling_team': 'Chennai Super Kings', 'target_overs': None, 'target_runs': None, 'year': 2009, 'city': 'Durban', 'date': datetime.datetime(2009, 4, 23, 0, 0), 'player_of_match': 'AB de Villiers', 'venue': 'Kingsmead', 'team1': 'Chennai Super Kings', 'team2': 'Delhi Capitals', 'toss_winner': 'Delhi Daredevils', 'toss_decision': 'bat', 'winner': 'Delhi Daredevils', 'result': 'runs', 'result_margin': 9.0, 'method': None, 'players': 'PA Patel, ML Hayden, SK Raina, MS Dhoni, A Flintoff, JA Morkel, S Badrinath, MS Gony, Joginder Sharma, L Balaji, M Muralitharan, G Gambhir, V Sehwag, AB de Villiers, TM Dilshan, KD Karthik, MK Tiwary, DL Vettori, DP Nannes, AM Salvi, PJ Sangwan, A Nehra', 'umpire1': 'BR Doctrove', 'umpire2': 'SJA Taufel', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 189.0, 'total_wickets': 5, 'runs': 116, 'wickets': 4, 'runs_last_5_overs': 33, 'wickets_last_5_overs': 1, 'ball_no': 85, 'max_balls': 120, 'balls_remaining': 35, 'runs_scored_in_remaining_balls': 73, 'runs_required': 0, 'won': 1}, {'match_id': 392189, 'innings': 1, 'overs': 14, 'balls': 2, 'batsman': 'AB de Villiers', 'non_striker': 'MK Tiwary', 'bowler': 'A Flintoff', 'batsman_runs': 6.0, 'extra_runs': 0.0, 'total_runs': 6.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Delhi Capitals', 'bowling_team': 'Chennai Super Kings', 'target_overs': None, 'target_runs': None, 'year': 2009, 'city': 'Durban', 'date': datetime.datetime(2009, 4, 23, 0, 0), 'player_of_match': 'AB de Villiers', 'venue': 'Kingsmead', 'team1': 'Chennai Super Kings', 'team2': 'Delhi Capitals', 'toss_winner': 'Delhi Daredevils', 'toss_decision': 'bat', 'winner': 'Delhi Daredevils', 'result': 'runs', 'result_margin': 9.0, 'method': None, 'players': 'PA Patel, ML Hayden, SK Raina, MS Dhoni, A Flintoff, JA Morkel, S Badrinath, MS Gony, Joginder Sharma, L Balaji, M Muralitharan, G Gambhir, V Sehwag, AB de Villiers, TM Dilshan, KD Karthik, MK Tiwary, DL Vettori, DP Nannes, AM Salvi, PJ Sangwan, A Nehra', 'umpire1': 'BR Doctrove', 'umpire2': 'SJA Taufel', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 189.0, 'total_wickets': 5, 'runs': 122, 'wickets': 4, 'runs_last_5_overs': 35, 'wickets_last_5_overs': 1, 'ball_no': 86, 'max_balls': 120, 'balls_remaining': 34, 'runs_scored_in_remaining_balls': 67, 'runs_required': 0, 'won': 1}, {'match_id': 392189, 'innings': 1, 'overs': 14, 'balls': 3, 'batsman': 'AB de Villiers', 'non_striker': 'MK Tiwary', 'bowler': 'A Flintoff', 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Delhi Capitals', 'bowling_team': 'Chennai Super Kings', 'target_overs': None, 'target_runs': None, 'year': 2009, 'city': 'Durban', 'date': datetime.datetime(2009, 4, 23, 0, 0), 'player_of_match': 'AB de Villiers', 'venue': 'Kingsmead', 'team1': 'Chennai Super Kings', 'team2': 'Delhi Capitals', 'toss_winner': 'Delhi Daredevils', 'toss_decision': 'bat', 'winner': 'Delhi Daredevils', 'result': 'runs', 'result_margin': 9.0, 'method': None, 'players': 'PA Patel, ML Hayden, SK Raina, MS Dhoni, A Flintoff, JA Morkel, S Badrinath, MS Gony, Joginder Sharma, L Balaji, M Muralitharan, G Gambhir, V Sehwag, AB de Villiers, TM Dilshan, KD Karthik, MK Tiwary, DL Vettori, DP Nannes, AM Salvi, PJ Sangwan, A Nehra', 'umpire1': 'BR Doctrove', 'umpire2': 'SJA Taufel', 'playoff': 0, 'knockout': 0, 'final': 0, 'fin ...
# 2022-04-07 21:35:22,141 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, innings, overs, balls, batsman, non_striker, bowler, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, batting_team, bowling_team, target_overs, target_runs, year, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, method, players, umpire1, umpire2, playoff, knockout, final, final_score, total_wickets, runs, wickets, runs_last_5_overs, wickets_last_5_overs, ball_no, max_balls, balls_remaining, runs_scored_in_remaining_balls, runs_required, won) VALUES (%(match_id)s, %(innings)s, %(overs)s, %(balls)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(batting_team)s, %(bowling_team)s, %(target_overs)s, %(target_runs)s, %(year)s, %(city)s, %(date)s, %(player_of_match)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(winner)s, %(result)s, %(result_margin)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(playoff)s, %(knockout)s, %(final)s, %(final_score)s, %(total_wickets)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(ball_no)s, %(max_balls)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(won)s)
# 2022-04-07 21:35:22,141 INFO sqlalchemy.engine.Engine [cached since 33.68s ago] ({'match_id': 392210, 'innings': 2, 'overs': 12, 'balls': 1, 'batsman': 'IK Pathan', 'non_striker': 'Yuvraj Singh', 'bowler': 'YK Pathan', 'batsman_runs': 2.0, 'extra_runs': 0.0, 'total_runs': 2.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Punjab Kings', 'bowling_team': 'Rajasthan Royals', 'target_overs': 20.0, 'target_runs': 212.0, 'year': 2009, 'city': 'Durban', 'date': datetime.datetime(2009, 5, 5, 0, 0), 'player_of_match': 'GC Smith', 'venue': 'Kingsmead', 'team1': 'Punjab Kings', 'team2': 'Rajasthan Royals', 'toss_winner': 'Kings XI Punjab', 'toss_decision': 'field', 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 78.0, 'method': None, 'players': 'S Sohal, KC Sangakkara, K Goel, SM Katich, DPMD Jayawardene, Yuvraj Singh, IK Pathan, PP Chawla, RR Powar, S Sreesanth, YA Abdulla, NV Ojha, GC Smith, YK Pathan, RA Jadeja, LA Carseldine, AS Raut, NK Patel, SK Warne, SM Harwood, SK Trivedi, A Singh', 'umpire1': 'SS Hazare', 'umpire2': 'IL Howell', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 133.0, 'total_wickets': 8, 'runs': 76, 'wickets': 5, 'runs_last_5_overs': 32, 'wickets_last_5_overs': 0, 'ball_no': 73, 'max_balls': 120, 'balls_remaining': 47, 'runs_scored_in_remaining_balls': 0, 'runs_required': 136, 'won': 0}, {'match_id': 392210, 'innings': 2, 'overs': 12, 'balls': 2, 'batsman': 'IK Pathan', 'non_striker': 'Yuvraj Singh', 'bowler': 'YK Pathan', 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Punjab Kings', 'bowling_team': 'Rajasthan Royals', 'target_overs': 20.0, 'target_runs': 212.0, 'year': 2009, 'city': 'Durban', 'date': datetime.datetime(2009, 5, 5, 0, 0), 'player_of_match': 'GC Smith', 'venue': 'Kingsmead', 'team1': 'Punjab Kings', 'team2': 'Rajasthan Royals', 'toss_winner': 'Kings XI Punjab', 'toss_decision': 'field', 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 78.0, 'method': None, 'players': 'S Sohal, KC Sangakkara, K Goel, SM Katich, DPMD Jayawardene, Yuvraj Singh, IK Pathan, PP Chawla, RR Powar, S Sreesanth, YA Abdulla, NV Ojha, GC Smith, YK Pathan, RA Jadeja, LA Carseldine, AS Raut, NK Patel, SK Warne, SM Harwood, SK Trivedi, A Singh', 'umpire1': 'SS Hazare', 'umpire2': 'IL Howell', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 133.0, 'total_wickets': 8, 'runs': 77, 'wickets': 5, 'runs_last_5_overs': 33, 'wickets_last_5_overs': 0, 'ball_no': 74, 'max_balls': 120, 'balls_remaining': 46, 'runs_scored_in_remaining_balls': 0, 'runs_required': 135, 'won': 0}, {'match_id': 392210, 'innings': 2, 'overs': 12, 'balls': 3, 'batsman': 'Yuvraj Singh', 'non_striker': 'IK Pathan', 'bowler': 'YK Pathan', 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Punjab Kings', 'bowling_team': 'Rajasthan Royals', 'target_overs': 20.0, 'target_runs': 212.0, 'year': 2009, 'city': 'Durban', 'date': datetime.datetime(2009, 5, 5, 0, 0), 'player_of_match': 'GC Smith', 'venue': 'Kingsmead', 'team1': 'Punjab Kings', 'team2': 'Rajasthan Royals', 'toss_winner': 'Kings XI Punjab', 'toss_decision': 'field', 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 78.0, 'method': None, 'players': 'S Sohal, KC Sangakkara, K Goel, SM Katich, DPMD Jayawardene, Yuvraj Singh, IK Pathan, PP Chawla, RR Powar, S Sreesanth, YA Abdulla, NV Ojha, GC Smith, YK Pathan, RA Jadeja, LA Carseldine, AS Raut, NK Patel, SK Warne, SM Harwood, SK Trivedi, A Singh', 'umpire1': 'SS Hazare', 'umpire2': 'IL Howell', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 133.0, 'total_wickets': 8, 'runs': 81, 'wickets': 5, 'runs_last_ ...
# 2022-04-07 21:35:32,035 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, innings, overs, balls, batsman, non_striker, bowler, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, batting_team, bowling_team, target_overs, target_runs, year, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, method, players, umpire1, umpire2, playoff, knockout, final, final_score, total_wickets, runs, wickets, runs_last_5_overs, wickets_last_5_overs, ball_no, max_balls, balls_remaining, runs_scored_in_remaining_balls, runs_required, won) VALUES (%(match_id)s, %(innings)s, %(overs)s, %(balls)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(batting_team)s, %(bowling_team)s, %(target_overs)s, %(target_runs)s, %(year)s, %(city)s, %(date)s, %(player_of_match)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(winner)s, %(result)s, %(result_margin)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(playoff)s, %(knockout)s, %(final)s, %(final_score)s, %(total_wickets)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(ball_no)s, %(max_balls)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(won)s)
# 2022-04-07 21:35:32,035 INFO sqlalchemy.engine.Engine [cached since 43.58s ago] ({'match_id': 392231, 'innings': 1, 'overs': 16, 'balls': 1, 'batsman': 'SK Raina', 'non_striker': 'MS Dhoni', 'bowler': 'AB Dinda', 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Chennai Super Kings', 'bowling_team': 'Kolkata Knight Riders', 'target_overs': None, 'target_runs': None, 'year': 2009, 'city': 'Centurion', 'date': datetime.datetime(2009, 5, 18, 0, 0), 'player_of_match': 'BJ Hodge', 'venue': 'SuperSport Park', 'team1': 'Chennai Super Kings', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Chennai Super Kings', 'toss_decision': 'bat', 'winner': 'Kolkata Knight Riders', 'result': 'wickets', 'result_margin': 7.0, 'method': None, 'players': 'PA Patel, GJ Bailey, SK Raina, MS Dhoni, JA Morkel, S Badrinath, JDP Oram, SB Jakati, L Balaji, M Muralitharan, S Tyagi, BB McCullum, SC Ganguly, BJ Hodge, DJ Hussey, WP Saha, LR Shukla, AB Agarkar, Anureet Singh, M Kartik, AB Dinda, BAW Mendis', 'umpire1': 'SJA Taufel', 'umpire2': 'RB Tiffin', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 188.0, 'total_wickets': 3, 'runs': 141, 'wickets': 2, 'runs_last_5_overs': 46, 'wickets_last_5_overs': 0, 'ball_no': 97, 'max_balls': 120, 'balls_remaining': 23, 'runs_scored_in_remaining_balls': 47, 'runs_required': 0, 'won': 0}, {'match_id': 392231, 'innings': 1, 'overs': 16, 'balls': 2, 'batsman': 'MS Dhoni', 'non_striker': 'SK Raina', 'bowler': 'AB Dinda', 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Chennai Super Kings', 'bowling_team': 'Kolkata Knight Riders', 'target_overs': None, 'target_runs': None, 'year': 2009, 'city': 'Centurion', 'date': datetime.datetime(2009, 5, 18, 0, 0), 'player_of_match': 'BJ Hodge', 'venue': 'SuperSport Park', 'team1': 'Chennai Super Kings', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Chennai Super Kings', 'toss_decision': 'bat', 'winner': 'Kolkata Knight Riders', 'result': 'wickets', 'result_margin': 7.0, 'method': None, 'players': 'PA Patel, GJ Bailey, SK Raina, MS Dhoni, JA Morkel, S Badrinath, JDP Oram, SB Jakati, L Balaji, M Muralitharan, S Tyagi, BB McCullum, SC Ganguly, BJ Hodge, DJ Hussey, WP Saha, LR Shukla, AB Agarkar, Anureet Singh, M Kartik, AB Dinda, BAW Mendis', 'umpire1': 'SJA Taufel', 'umpire2': 'RB Tiffin', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 188.0, 'total_wickets': 3, 'runs': 145, 'wickets': 2, 'runs_last_5_overs': 49, 'wickets_last_5_overs': 0, 'ball_no': 98, 'max_balls': 120, 'balls_remaining': 22, 'runs_scored_in_remaining_balls': 43, 'runs_required': 0, 'won': 0}, {'match_id': 392231, 'innings': 1, 'overs': 16, 'balls': 3, 'batsman': 'MS Dhoni', 'non_striker': 'SK Raina', 'bowler': 'AB Dinda', 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Chennai Super Kings', 'bowling_team': 'Kolkata Knight Riders', 'target_overs': None, 'target_runs': None, 'year': 2009, 'city': 'Centurion', 'date': datetime.datetime(2009, 5, 18, 0, 0), 'player_of_match': 'BJ Hodge', 'venue': 'SuperSport Park', 'team1': 'Chennai Super Kings', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Chennai Super Kings', 'toss_decision': 'bat', 'winner': 'Kolkata Knight Riders', 'result': 'wickets', 'result_margin': 7.0, 'method': None, 'players': 'PA Patel, GJ Bailey, SK Raina, MS Dhoni, JA Morkel, S Badrinath, JDP Oram, SB Jakati, L Balaji, M Muralitharan, S Tyagi, BB McCullum, SC Ganguly, BJ Hodge, DJ Hussey, WP Saha, LR Shukla, AB Agarkar, Anureet Singh, M Kartik, AB Dinda, BAW Mendis', 'umpire1': 'SJA Taufel', 'umpire2': 'RB Tiffin', 'playoff': 0, 'knocko ...
# 2022-04-07 21:35:43,290 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, innings, overs, balls, batsman, non_striker, bowler, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, batting_team, bowling_team, target_overs, target_runs, year, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, method, players, umpire1, umpire2, playoff, knockout, final, final_score, total_wickets, runs, wickets, runs_last_5_overs, wickets_last_5_overs, ball_no, max_balls, balls_remaining, runs_scored_in_remaining_balls, runs_required, won) VALUES (%(match_id)s, %(innings)s, %(overs)s, %(balls)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(batting_team)s, %(bowling_team)s, %(target_overs)s, %(target_runs)s, %(year)s, %(city)s, %(date)s, %(player_of_match)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(winner)s, %(result)s, %(result_margin)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(playoff)s, %(knockout)s, %(final)s, %(final_score)s, %(total_wickets)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(ball_no)s, %(max_balls)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(won)s)
# 2022-04-07 21:35:43,290 INFO sqlalchemy.engine.Engine [cached since 54.83s ago] ({'match_id': 419118, 'innings': 1, 'overs': 4, 'balls': 4, 'batsman': 'FY Fazal', 'non_striker': 'NV Ojha', 'bowler': 'SE Bond', 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Rajasthan Royals', 'bowling_team': 'Kolkata Knight Riders', 'target_overs': None, 'target_runs': None, 'year': 2010, 'city': 'Ahmedabad', 'date': datetime.datetime(2010, 3, 20, 0, 0), 'player_of_match': 'AA Jhunjhunwala', 'venue': 'Narendra Modi Stadium', 'team1': 'Rajasthan Royals', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'bat', 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 34.0, 'method': None, 'players': 'MJ Lumb, NV Ojha, FY Fazal, AA Jhunjhunwala, YK Pathan, AC Voges, P Dogra, SK Warne, MM Patel, SK Trivedi, SW Tait, MK Tiwary, BJ Hodge, CA Pujara, SC Ganguly, OA Shah, AD Mathews, WP Saha, M Kartik, AB Dinda, SE Bond, I Sharma', 'umpire1': 'RE Koertzen', 'umpire2': 'RB Tiffin', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 168.0, 'total_wickets': 7, 'runs': 42, 'wickets': 1, 'runs_last_5_overs': 42, 'wickets_last_5_overs': 1, 'ball_no': 28, 'max_balls': 120, 'balls_remaining': 92, 'runs_scored_in_remaining_balls': 126, 'runs_required': 0, 'won': 1}, {'match_id': 419118, 'innings': 1, 'overs': 4, 'balls': 5, 'batsman': 'FY Fazal', 'non_striker': 'NV Ojha', 'bowler': 'SE Bond', 'batsman_runs': 0.0, 'extra_runs': 0.0, 'total_runs': 0.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Rajasthan Royals', 'bowling_team': 'Kolkata Knight Riders', 'target_overs': None, 'target_runs': None, 'year': 2010, 'city': 'Ahmedabad', 'date': datetime.datetime(2010, 3, 20, 0, 0), 'player_of_match': 'AA Jhunjhunwala', 'venue': 'Narendra Modi Stadium', 'team1': 'Rajasthan Royals', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'bat', 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 34.0, 'method': None, 'players': 'MJ Lumb, NV Ojha, FY Fazal, AA Jhunjhunwala, YK Pathan, AC Voges, P Dogra, SK Warne, MM Patel, SK Trivedi, SW Tait, MK Tiwary, BJ Hodge, CA Pujara, SC Ganguly, OA Shah, AD Mathews, WP Saha, M Kartik, AB Dinda, SE Bond, I Sharma', 'umpire1': 'RE Koertzen', 'umpire2': 'RB Tiffin', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 168.0, 'total_wickets': 7, 'runs': 42, 'wickets': 1, 'runs_last_5_overs': 42, 'wickets_last_5_overs': 1, 'ball_no': 29, 'max_balls': 120, 'balls_remaining': 91, 'runs_scored_in_remaining_balls': 126, 'runs_required': 0, 'won': 1}, {'match_id': 419118, 'innings': 1, 'overs': 5, 'balls': 0, 'batsman': 'FY Fazal', 'non_striker': 'NV Ojha', 'bowler': 'SE Bond', 'batsman_runs': 0.0, 'extra_runs': 0.0, 'total_runs': 0.0, 'non_boundary': 0, 'is_wicket': 1, 'dismissal_kind': 'caught', 'player_dismissed': 'FY Fazal', 'fielder': 'CA Pujara', 'extras_type': 'nan', 'batting_team': 'Rajasthan Royals', 'bowling_team': 'Kolkata Knight Riders', 'target_overs': None, 'target_runs': None, 'year': 2010, 'city': 'Ahmedabad', 'date': datetime.datetime(2010, 3, 20, 0, 0), 'player_of_match': 'AA Jhunjhunwala', 'venue': 'Narendra Modi Stadium', 'team1': 'Rajasthan Royals', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'bat', 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 34.0, 'method': None, 'players': 'MJ Lumb, NV Ojha, FY Fazal, AA Jhunjhunwala, YK Pathan, AC Voges, P Dogra, SK Warne, MM Patel, SK Trivedi, SW Tait, MK Tiwary, BJ Hodge, CA Pujara, SC Ganguly, OA Shah, AD Mathews, WP Saha, M Kartik, AB Dinda, SE Bond, I Sharma', 'umpire1': 'RE Koertzen', 'umpire2': 'RB Tiffin', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 168.0, 'total_ ...
# ...
# 2022-04-07 21:42:08,569 INFO sqlalchemy.engine.Engine [cached since 440.1s ago] ({'match_id': 1254084, 'innings': 2, 'overs': 17, 'balls': 3, 'batsman': 'KA Pollard', 'non_striker': 'HH Pandya', 'bowler': 'SN Thakur', 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Mumbai Indians', 'bowling_team': 'Chennai Super Kings', 'target_overs': 20.0, 'target_runs': 219.0, 'year': 2021, 'city': 'Delhi', 'date': datetime.datetime(2021, 5, 1, 0, 0), 'player_of_match': 'KA Pollard', 'venue': 'Arun Jaitley Stadium', 'team1': 'Chennai Super Kings', 'team2': 'Mumbai Indians', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'field', 'winner': 'Mumbai Indians', 'result': 'wickets', 'result_margin': 4.0, 'method': None, 'players': 'RD Gaikwad, F du Plessis, MM Ali, SK Raina, AT Rayudu, RA Jadeja, MS Dhoni, SM Curran, SN Thakur, DL Chahar, L Ngidi, Q de Kock, RG Sharma, SA Yadav, KH Pandya, KA Pollard, HH Pandya, JDS Neesham, DS Kulkarni, RD Chahar, JJ Bumrah, TA Boult', 'umpire1': 'KN Ananthapadmanabhan', 'umpire2': 'CK Nandan', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 219.0, 'total_wickets': 6, 'runs': 183, 'wickets': 4, 'runs_last_5_overs': 68, 'wickets_last_5_overs': 1, 'ball_no': 105, 'max_balls': 120, 'balls_remaining': 15, 'runs_scored_in_remaining_balls': 0, 'runs_required': 36, 'won': 1}, {'match_id': 1254084, 'innings': 2, 'overs': 17, 'balls': 4, 'batsman': 'KA Pollard', 'non_striker': 'HH Pandya', 'bowler': 'SN Thakur', 'batsman_runs': 2.0, 'extra_runs': 0.0, 'total_runs': 2.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Mumbai Indians', 'bowling_team': 'Chennai Super Kings', 'target_overs': 20.0, 'target_runs': 219.0, 'year': 2021, 'city': 'Delhi', 'date': datetime.datetime(2021, 5, 1, 0, 0), 'player_of_match': 'KA Pollard', 'venue': 'Arun Jaitley Stadium', 'team1': 'Chennai Super Kings', 'team2': 'Mumbai Indians', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'field', 'winner': 'Mumbai Indians', 'result': 'wickets', 'result_margin': 4.0, 'method': None, 'players': 'RD Gaikwad, F du Plessis, MM Ali, SK Raina, AT Rayudu, RA Jadeja, MS Dhoni, SM Curran, SN Thakur, DL Chahar, L Ngidi, Q de Kock, RG Sharma, SA Yadav, KH Pandya, KA Pollard, HH Pandya, JDS Neesham, DS Kulkarni, RD Chahar, JJ Bumrah, TA Boult', 'umpire1': 'KN Ananthapadmanabhan', 'umpire2': 'CK Nandan', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 219.0, 'total_wickets': 6, 'runs': 185, 'wickets': 4, 'runs_last_5_overs': 69, 'wickets_last_5_overs': 1, 'ball_no': 106, 'max_balls': 120, 'balls_remaining': 14, 'runs_scored_in_remaining_balls': 0, 'runs_required': 34, 'won': 1}, {'match_id': 1254084, 'innings': 2, 'overs': 17, 'balls': 5, 'batsman': 'KA Pollard', 'non_striker': 'HH Pandya', 'bowler': 'SN Thakur', 'batsman_runs': 2.0, 'extra_runs': 0.0, 'total_runs': 2.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Mumbai Indians', 'bowling_team': 'Chennai Super Kings', 'target_overs': 20.0, 'target_runs': 219.0, 'year': 2021, 'city': 'Delhi', 'date': datetime.datetime(2021, 5, 1, 0, 0), 'player_of_match': 'KA Pollard', 'venue': 'Arun Jaitley Stadium', 'team1': 'Chennai Super Kings', 'team2': 'Mumbai Indians', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'field', 'winner': 'Mumbai Indians', 'result': 'wickets', 'result_margin': 4.0, 'method': None, 'players': 'RD Gaikwad, F du Plessis, MM Ali, SK Raina, AT Rayudu, RA Jadeja, MS Dhoni, SM Curran, SN Thakur, DL Chahar, L Ngidi, Q de Kock, RG Sharma, SA Yadav, KH Pandya, KA Pollard, HH Pandya, JDS Neesham, DS Kulkarni, RD Chahar, JJ Bumrah, TA Boult', 'umpire1': 'KN Ananthapadmanabhan', 'umpire2': 'CK Nandan', 'playoff': 0, 'knockout': 0, 'final': 0, 'fina ...
# 2022-04-07 21:42:18,372 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, innings, overs, balls, batsman, non_striker, bowler, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, batting_team, bowling_team, target_overs, target_runs, year, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, method, players, umpire1, umpire2, playoff, knockout, final, final_score, total_wickets, runs, wickets, runs_last_5_overs, wickets_last_5_overs, ball_no, max_balls, balls_remaining, runs_scored_in_remaining_balls, runs_required, won) VALUES (%(match_id)s, %(innings)s, %(overs)s, %(balls)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(batting_team)s, %(bowling_team)s, %(target_overs)s, %(target_runs)s, %(year)s, %(city)s, %(date)s, %(player_of_match)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(winner)s, %(result)s, %(result_margin)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(playoff)s, %(knockout)s, %(final)s, %(final_score)s, %(total_wickets)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(ball_no)s, %(max_balls)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(won)s)
# 2022-04-07 21:42:18,372 INFO sqlalchemy.engine.Engine [cached since 449.9s ago] ({'match_id': 1254106, 'innings': 1, 'overs': 7, 'balls': 5, 'batsman': 'VR Iyer', 'non_striker': 'Shubman Gill', 'bowler': 'Mustafizur Rahman', 'batsman_runs': 0.0, 'extra_runs': 0.0, 'total_runs': 0.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Rajasthan Royals', 'target_overs': None, 'target_runs': None, 'year': 2021, 'city': 'Sharjah', 'date': datetime.datetime(2021, 10, 7, 0, 0), 'player_of_match': 'Shivam Mavi', 'venue': 'Sharjah Cricket Stadium', 'team1': 'Kolkata Knight Riders', 'team2': 'Rajasthan Royals', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'field', 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 86.0, 'method': None, 'players': 'Shubman Gill, VR Iyer, N Rana, RA Tripathi, KD Karthik, EJG Morgan, Shakib Al Hasan, SP Narine, LH Ferguson, CV Varun, Shivam Mavi, YBK Jaiswal, LS Livingstone, SV Samson, S Dube, Anuj Rawat, GD Phillips, R Tewatia, CH Morris, JD Unadkat, C Sakariya, Mustafizur Rahman', 'umpire1': 'MA Gough', 'umpire2': 'HAS Khalid', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 171.0, 'total_wickets': 4, 'runs': 49, 'wickets': 0, 'runs_last_5_overs': 32, 'wickets_last_5_overs': 0, 'ball_no': 47, 'max_balls': 120, 'balls_remaining': 73, 'runs_scored_in_remaining_balls': 122, 'runs_required': 0, 'won': 1}, {'match_id': 1254106, 'innings': 1, 'overs': 8, 'balls': 0, 'batsman': 'VR Iyer', 'non_striker': 'Shubman Gill', 'bowler': 'Mustafizur Rahman', 'batsman_runs': 0.0, 'extra_runs': 1.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'legbyes', 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Rajasthan Royals', 'target_overs': None, 'target_runs': None, 'year': 2021, 'city': 'Sharjah', 'date': datetime.datetime(2021, 10, 7, 0, 0), 'player_of_match': 'Shivam Mavi', 'venue': 'Sharjah Cricket Stadium', 'team1': 'Kolkata Knight Riders', 'team2': 'Rajasthan Royals', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'field', 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 86.0, 'method': None, 'players': 'Shubman Gill, VR Iyer, N Rana, RA Tripathi, KD Karthik, EJG Morgan, Shakib Al Hasan, SP Narine, LH Ferguson, CV Varun, Shivam Mavi, YBK Jaiswal, LS Livingstone, SV Samson, S Dube, Anuj Rawat, GD Phillips, R Tewatia, CH Morris, JD Unadkat, C Sakariya, Mustafizur Rahman', 'umpire1': 'MA Gough', 'umpire2': 'HAS Khalid', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 171.0, 'total_wickets': 4, 'runs': 50, 'wickets': 0, 'runs_last_5_overs': 33, 'wickets_last_5_overs': 0, 'ball_no': 48, 'max_balls': 120, 'balls_remaining': 72, 'runs_scored_in_remaining_balls': 121, 'runs_required': 0, 'won': 1}, {'match_id': 1254106, 'innings': 1, 'overs': 8, 'balls': 1, 'batsman': 'VR Iyer', 'non_striker': 'Shubman Gill', 'bowler': 'S Dube', 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Rajasthan Royals', 'target_overs': None, 'target_runs': None, 'year': 2021, 'city': 'Sharjah', 'date': datetime.datetime(2021, 10, 7, 0, 0), 'player_of_match': 'Shivam Mavi', 'venue': 'Sharjah Cricket Stadium', 'team1': 'Kolkata Knight Riders', 'team2': 'Rajasthan Royals', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'field', 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 86.0, 'method': None, 'players': 'Shubman Gill, VR Iyer, N Rana, RA Tripathi, KD Karthik, EJG Morgan, Shakib Al Hasan, SP Narine, LH Ferguson, CV Varun, Shivam Mavi, YBK Jaiswal, LS Livingstone, SV Samson, S Dube, Anuj Rawat, GD Phillips, R Tewatia, CH Morris, JD Unadkat, C S ...
# 2022-04-07 21:42:27,339 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, innings, overs, balls, batsman, non_striker, bowler, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, batting_team, bowling_team, target_overs, target_runs, year, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, method, players, umpire1, umpire2, playoff, knockout, final, final_score, total_wickets, runs, wickets, runs_last_5_overs, wickets_last_5_overs, ball_no, max_balls, balls_remaining, runs_scored_in_remaining_balls, runs_required, won) VALUES (%(match_id)s, %(innings)s, %(overs)s, %(balls)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(batting_team)s, %(bowling_team)s, %(target_overs)s, %(target_runs)s, %(year)s, %(city)s, %(date)s, %(player_of_match)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(winner)s, %(result)s, %(result_margin)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(playoff)s, %(knockout)s, %(final)s, %(final_score)s, %(total_wickets)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(ball_no)s, %(max_balls)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(won)s)
# 2022-04-07 21:42:27,339 INFO sqlalchemy.engine.Engine [cached since 458.9s ago] ({'match_id': 1304055, 'innings': 2, 'overs': 10, 'balls': 5, 'batsman': 'Ishan Kishan', 'non_striker': 'Tilak Varma', 'bowler': 'R Ashwin', 'batsman_runs': 2.0, 'extra_runs': 0.0, 'total_runs': 2.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Mumbai Indians', 'bowling_team': 'Rajasthan Royals', 'target_overs': 20.0, 'target_runs': 194.0, 'year': 2022, 'city': 'Mumbai', 'date': datetime.datetime(2022, 4, 2, 0, 0), 'player_of_match': 'JC Buttler', 'venue': 'Dr DY Patil Sports Academy, Mumbai', 'team1': 'Rajasthan Royals', 'team2': 'Mumbai Indians', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'field', 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 23.0, 'method': None, 'players': 'JC Buttler, YBK Jaiswal, D Padikkal, SV Samson, SO Hetmyer, R Parag, R Ashwin, Navdeep Saini, TA Boult, YS Chahal, M Prasidh Krishna, Ishan Kishan, RG Sharma, Anmolpreet Singh, Tilak Varma, KA Pollard, TH David, DR Sams, M Ashwin, JJ Bumrah, TS Mills, Basil Thampi', 'umpire1': 'Nitin Menon', 'umpire2': 'PG Pathak', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 170.0, 'total_wickets': 8, 'runs': 100, 'wickets': 2, 'runs_last_5_overs': 50, 'wickets_last_5_overs': 0, 'ball_no': 65, 'max_balls': 120, 'balls_remaining': 55, 'runs_scored_in_remaining_balls': 0, 'runs_required': 94, 'won': 0}, {'match_id': 1304055, 'innings': 2, 'overs': 11, 'balls': 0, 'batsman': 'Ishan Kishan', 'non_striker': 'Tilak Varma', 'bowler': 'R Ashwin', 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Mumbai Indians', 'bowling_team': 'Rajasthan Royals', 'target_overs': 20.0, 'target_runs': 194.0, 'year': 2022, 'city': 'Mumbai', 'date': datetime.datetime(2022, 4, 2, 0, 0), 'player_of_match': 'JC Buttler', 'venue': 'Dr DY Patil Sports Academy, Mumbai', 'team1': 'Rajasthan Royals', 'team2': 'Mumbai Indians', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'field', 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 23.0, 'method': None, 'players': 'JC Buttler, YBK Jaiswal, D Padikkal, SV Samson, SO Hetmyer, R Parag, R Ashwin, Navdeep Saini, TA Boult, YS Chahal, M Prasidh Krishna, Ishan Kishan, RG Sharma, Anmolpreet Singh, Tilak Varma, KA Pollard, TH David, DR Sams, M Ashwin, JJ Bumrah, TS Mills, Basil Thampi', 'umpire1': 'Nitin Menon', 'umpire2': 'PG Pathak', 'playoff': 0, 'knockout': 0, 'final': 0, 'final_score': 170.0, 'total_wickets': 8, 'runs': 101, 'wickets': 2, 'runs_last_5_overs': 51, 'wickets_last_5_overs': 0, 'ball_no': 66, 'max_balls': 120, 'balls_remaining': 54, 'runs_scored_in_remaining_balls': 0, 'runs_required': 93, 'won': 0}, {'match_id': 1304055, 'innings': 2, 'overs': 11, 'balls': 1, 'batsman': 'Ishan Kishan', 'non_striker': 'Tilak Varma', 'bowler': 'R Parag', 'batsman_runs': 2.0, 'extra_runs': 0.0, 'total_runs': 2.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'nan', 'batting_team': 'Mumbai Indians', 'bowling_team': 'Rajasthan Royals', 'target_overs': 20.0, 'target_runs': 194.0, 'year': 2022, 'city': 'Mumbai', 'date': datetime.datetime(2022, 4, 2, 0, 0), 'player_of_match': 'JC Buttler', 'venue': 'Dr DY Patil Sports Academy, Mumbai', 'team1': 'Rajasthan Royals', 'team2': 'Mumbai Indians', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'field', 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 23.0, 'method': None, 'players': 'JC Buttler, YBK Jaiswal, D Padikkal, SV Samson, SO Hetmyer, R Parag, R Ashwin, Navdeep Saini, TA Boult, YS Chahal, M Prasidh Krishna, Ishan Kishan, RG Sharma, Anmolpreet Singh, Tilak Varma, KA Pollard, TH David, DR Sams, M Ashwin, JJ Bumrah, TS Mills, Basil Thampi', 'umpire1': 'Nitin Men ...
# 2022-04-07 21:42:29,585 INFO sqlalchemy.engine.Engine COMMIT
# Data pushed to DB.
# Files moved to Matches folder.
