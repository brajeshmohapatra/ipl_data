# %%
import os
import json
import warnings
import numpy as np
import pandas as pd
from IPython.core.display import display, HTML
warnings.filterwarnings('ignore')
pd.pandas.set_option('display.max_rows', None)
pd.pandas.set_option('display.max_columns', None)
display(HTML('<style>.container{width : 100% ! important;}</style>'))
# Out:
# <style>.container{width : 100% ! important;}</style>

# %%
file = open('Matches/1082591.json')

# %%
data = json.load(file)

# %%
data['innings'][0]['overs'][1]['deliveries'][4]['wickets'][0]['kind']
# Out:
# 'caught'

# %%
data
# Out:
# {'meta': {'data_version': '1.0.0', 'created': '2017-04-06', 'revision': 1},
#  'info': {'balls_per_over': 6,
#   'city': 'Hyderabad',
#   'dates': ['2017-04-05'],
#   'event': {'match_number': 1, 'name': 'Indian Premier League'},
#   'gender': 'male',
#   'match_type': 'T20',
#   'officials': {'match_referees': ['J Srinath'],
#    'reserve_umpires': ['N Pandit'],
#    'tv_umpires': ['A Deshmukh'],
#    'umpires': ['AY Dandekar', 'NJ Llong']},
#   'outcome': {'by': {'runs': 35}, 'winner': 'Sunrisers Hyderabad'},
#   'overs': 20,
#   'player_of_match': ['Yuvraj Singh'],
#   'players': {'Royal Challengers Bangalore': ['CH Gayle',
#     'Mandeep Singh',
#     'TM Head',
#     'KM Jadhav',
#     'SR Watson',
#     'Sachin Baby',
#     'STR Binny',
#     'S Aravind',
#     'TS Mills',
#     'YS Chahal',
#     'A Choudhary'],
#    'Sunrisers Hyderabad': ['DA Warner',
#     'S Dhawan',
#     'MC Henriques',
#     'Yuvraj Singh',
#     'DJ Hooda',
#     'BCJ Cutting',
#     'NV Ojha',
#     'Bipul Sharma',
#     'B Kumar',
#     'A Nehra',
#     'Rashid Khan']},
#   'registry': {'people': {'A Choudhary': '18e6906e',
#     'A Deshmukh': '6fda55cc',
#     'A Nehra': '96fd40ae',
#     'AY Dandekar': '2efc430e',
#     'B Kumar': '2e81a32d',
#     'BCJ Cutting': '2e11c706',
#     'Bipul Sharma': 'c18496e1',
#     'CH Gayle': 'db584dad',
#     'CJ Jordan': 'ffe699c0',
#     'DA Warner': 'dcce6f09',
#     'DJ Hooda': '73ad96ed',
#     'J Srinath': 'bad31fac',
#     'KM Jadhav': '99d63244',
#     'MC Henriques': '32198ae0',
#     'Mandeep Singh': 'c3a96caf',
#     'N Pandit': '4947c258',
#     'NJ Llong': '573fb985',
#     'NV Ojha': '890946a0',
#     'Rashid Khan': '5f547c8b',
#     'S Aravind': '957532de',
#     'S Dhawan': '0a476045',
#     'SR Watson': '4329fbb5',
#     'STR Binny': 'bd17b45f',
#     'Sachin Baby': 'dc9dd038',
#     'TM Head': '12b610c2',
#     'TS Mills': '245c97cb',
#     'YS Chahal': '57ee1fde',
#     'Yuvraj Singh': '1c914163'}},
#   'season': 2017,
#   'team_type': 'club',
#   'teams': ['Sunrisers Hyderabad', 'Royal Challengers Bangalore'],
#   'toss': {'decision': 'field', 'winner': 'Royal Challengers Bangalore'},
#   'venue': 'Rajiv Gandhi International Stadium, Uppal'},
#  'innings': [{'team': 'Sunrisers Hyderabad',
#    'overs': [{'over': 0,
#      'deliveries': [{'batter': 'DA Warner',
#        'bowler': 'TS Mills',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DA Warner',
#        'bowler': 'TS Mills',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DA Warner',
#        'bowler': 'TS Mills',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'DA Warner',
#        'bowler': 'TS Mills',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DA Warner',
#        'bowler': 'TS Mills',
#        'extras': {'wides': 2},
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 0, 'extras': 2, 'total': 2}},
#       {'batter': 'S Dhawan',
#        'bowler': 'TS Mills',
#        'non_striker': 'DA Warner',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'S Dhawan',
#        'bowler': 'TS Mills',
#        'extras': {'legbyes': 1},
#        'non_striker': 'DA Warner',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}}]},
#     {'over': 1,
#      'deliveries': [{'batter': 'S Dhawan',
#        'bowler': 'A Choudhary',
#        'non_striker': 'DA Warner',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DA Warner',
#        'bowler': 'A Choudhary',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'DA Warner',
#        'bowler': 'A Choudhary',
#        'extras': {'noballs': 1},
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'DA Warner',
#        'bowler': 'A Choudhary',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'DA Warner',
#        'bowler': 'A Choudhary',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'DA Warner',
#          'fielders': [{'name': 'Mandeep Singh'}]}]},
#       {'batter': 'MC Henriques',
#        'bowler': 'A Choudhary',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MC Henriques',
#        'bowler': 'A Choudhary',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 2,
#      'deliveries': [{'batter': 'S Dhawan',
#        'bowler': 'TS Mills',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'TS Mills',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MC Henriques',
#        'bowler': 'TS Mills',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MC Henriques',
#        'bowler': 'TS Mills',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 3, 'extras': 0, 'total': 3}},
#       {'batter': 'S Dhawan',
#        'bowler': 'TS Mills',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'TS Mills',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 3,
#      'deliveries': [{'batter': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'S Dhawan',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'S Dhawan',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'S Dhawan',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 4,
#      'deliveries': [{'batter': 'S Dhawan',
#        'bowler': 'S Aravind',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'S Aravind',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'S Dhawan',
#        'bowler': 'S Aravind',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'S Aravind',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'MC Henriques',
#        'bowler': 'S Aravind',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'MC Henriques',
#        'bowler': 'S Aravind',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 5,
#      'deliveries': [{'batter': 'S Dhawan',
#        'bowler': 'SR Watson',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'S Dhawan',
#        'bowler': 'SR Watson',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'S Dhawan',
#        'bowler': 'SR Watson',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'S Dhawan',
#        'bowler': 'SR Watson',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'S Dhawan',
#        'bowler': 'SR Watson',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'S Dhawan',
#        'bowler': 'SR Watson',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 6,
#      'deliveries': [{'batter': 'S Dhawan',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'S Dhawan',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'S Dhawan',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 7,
#      'deliveries': [{'batter': 'S Dhawan',
#        'bowler': 'TM Head',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'TM Head',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'S Dhawan',
#        'bowler': 'TM Head',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'TM Head',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'MC Henriques',
#        'bowler': 'TM Head',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'S Dhawan',
#        'bowler': 'TM Head',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 8,
#      'deliveries': [{'batter': 'S Dhawan',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'S Dhawan',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'S Dhawan',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#     {'over': 9,
#      'deliveries': [{'batter': 'S Dhawan',
#        'bowler': 'A Choudhary',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'S Dhawan',
#        'bowler': 'A Choudhary',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'A Choudhary',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'S Dhawan',
#        'bowler': 'A Choudhary',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'A Choudhary',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'S Dhawan',
#        'bowler': 'A Choudhary',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 10,
#      'deliveries': [{'batter': 'MC Henriques',
#        'bowler': 'STR Binny',
#        'non_striker': 'S Dhawan',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'S Dhawan',
#        'bowler': 'STR Binny',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'S Dhawan',
#        'bowler': 'STR Binny',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'S Dhawan',
#          'fielders': [{'name': 'Sachin Baby'}]}]},
#       {'batter': 'MC Henriques',
#        'bowler': 'STR Binny',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'STR Binny',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'STR Binny',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#     {'over': 11,
#      'deliveries': [{'batter': 'MC Henriques',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'S Aravind',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'S Aravind',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'S Aravind',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'S Aravind',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 12,
#      'deliveries': [{'batter': 'Yuvraj Singh',
#        'bowler': 'A Choudhary',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'A Choudhary',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'A Choudhary',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'A Choudhary',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'A Choudhary',
#        'extras': {'wides': 1},
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'A Choudhary',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'A Choudhary',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 13,
#      'deliveries': [{'batter': 'Yuvraj Singh',
#        'bowler': 'SR Watson',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'SR Watson',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'SR Watson',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'SR Watson',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'SR Watson',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MC Henriques',
#        'bowler': 'SR Watson',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 14,
#      'deliveries': [{'batter': 'MC Henriques',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'MC Henriques',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'S Aravind',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'S Aravind',
#        'non_striker': 'MC Henriques',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MC Henriques',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'MC Henriques',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 15,
#      'deliveries': [{'batter': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'MC Henriques',
#          'fielders': [{'name': 'Sachin Baby'}]}]},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DJ Hooda',
#        'bowler': 'YS Chahal',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DJ Hooda',
#        'bowler': 'YS Chahal',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 16,
#      'deliveries': [{'batter': 'DJ Hooda',
#        'bowler': 'TS Mills',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'TS Mills',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'TS Mills',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'TS Mills',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DJ Hooda',
#        'bowler': 'TS Mills',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DJ Hooda',
#        'bowler': 'TS Mills',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 17,
#      'deliveries': [{'batter': 'DJ Hooda',
#        'bowler': 'A Choudhary',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'DJ Hooda',
#        'bowler': 'A Choudhary',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'A Choudhary',
#        'extras': {'wides': 1},
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'A Choudhary',
#        'extras': {'wides': 1},
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'A Choudhary',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'A Choudhary',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DJ Hooda',
#        'bowler': 'A Choudhary',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'DJ Hooda',
#        'bowler': 'A Choudhary',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 18,
#      'deliveries': [{'batter': 'DJ Hooda',
#        'bowler': 'TS Mills',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'TS Mills',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'TS Mills',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'Yuvraj Singh',
#        'bowler': 'TS Mills',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'bowled', 'player_out': 'Yuvraj Singh'}]},
#       {'batter': 'BCJ Cutting',
#        'bowler': 'TS Mills',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DJ Hooda',
#        'bowler': 'TS Mills',
#        'non_striker': 'BCJ Cutting',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 19,
#      'deliveries': [{'batter': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DJ Hooda',
#        'bowler': 'SR Watson',
#        'non_striker': 'BCJ Cutting',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}}]}],
#    'powerplays': [{'from': 0.1, 'to': 5.6, 'type': 'mandatory'}]},
#   {'team': 'Royal Challengers Bangalore',
#    'overs': [{'over': 0,
#      'deliveries': [{'batter': 'CH Gayle',
#        'bowler': 'A Nehra',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'A Nehra',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'A Nehra',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'A Nehra',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'A Nehra',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'A Nehra',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 1,
#      'deliveries': [{'batter': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'B Kumar',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'B Kumar',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'B Kumar',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 2,
#      'deliveries': [{'batter': 'CH Gayle',
#        'bowler': 'A Nehra',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CH Gayle',
#        'bowler': 'A Nehra',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'CH Gayle',
#        'bowler': 'A Nehra',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'A Nehra',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'A Nehra',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CH Gayle',
#        'bowler': 'A Nehra',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}}]},
#     {'over': 3,
#      'deliveries': [{'batter': 'Mandeep Singh',
#        'bowler': 'B Kumar',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'extras': {'wides': 1},
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'B Kumar',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 4,
#      'deliveries': [{'batter': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'extras': {'wides': 1},
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'Mandeep Singh',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 5,
#      'deliveries': [{'batter': 'Mandeep Singh',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'Mandeep Singh',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'bowled', 'player_out': 'Mandeep Singh'}]},
#       {'batter': 'TM Head',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'TM Head',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'CH Gayle',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 6,
#      'deliveries': [{'batter': 'CH Gayle',
#        'bowler': 'DJ Hooda',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'CH Gayle',
#        'bowler': 'DJ Hooda',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'CH Gayle',
#        'bowler': 'DJ Hooda',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'CH Gayle',
#          'fielders': [{'name': 'DA Warner'}]}]},
#       {'batter': 'TM Head',
#        'bowler': 'DJ Hooda',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TM Head',
#        'bowler': 'DJ Hooda',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'DJ Hooda',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 7,
#      'deliveries': [{'batter': 'TM Head',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'TM Head',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'TM Head',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TM Head',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 8,
#      'deliveries': [{'batter': 'TM Head',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'BCJ Cutting',
#        'extras': {'wides': 1},
#        'non_striker': 'TM Head',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TM Head',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 9,
#      'deliveries': [{'batter': 'KM Jadhav',
#        'bowler': 'MC Henriques',
#        'extras': {'noballs': 1},
#        'non_striker': 'TM Head',
#        'runs': {'batter': 1, 'extras': 1, 'total': 2}},
#       {'batter': 'TM Head',
#        'bowler': 'MC Henriques',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'TM Head',
#        'bowler': 'MC Henriques',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'MC Henriques',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TM Head',
#        'bowler': 'MC Henriques',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TM Head',
#        'bowler': 'MC Henriques',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'MC Henriques',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 10,
#      'deliveries': [{'batter': 'TM Head',
#        'bowler': 'A Nehra',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'A Nehra',
#        'extras': {'wides': 1},
#        'non_striker': 'TM Head',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'A Nehra',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TM Head',
#        'bowler': 'A Nehra',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'A Nehra',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'A Nehra',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'A Nehra',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 11,
#      'deliveries': [{'batter': 'KM Jadhav',
#        'bowler': 'MC Henriques',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TM Head',
#        'bowler': 'MC Henriques',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'TM Head',
#        'bowler': 'MC Henriques',
#        'non_striker': 'KM Jadhav',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KM Jadhav',
#        'bowler': 'MC Henriques',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1},
#        'wickets': [{'kind': 'run out',
#          'player_out': 'KM Jadhav',
#          'fielders': [{'name': 'BCJ Cutting'}]}]},
#       {'batter': 'SR Watson',
#        'bowler': 'MC Henriques',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TM Head',
#        'bowler': 'MC Henriques',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 12,
#      'deliveries': [{'batter': 'TM Head',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SR Watson',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'SR Watson',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'TM Head',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TM Head',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'TM Head',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'TM Head',
#          'fielders': [{'name': 'Yuvraj Singh'}]}]},
#       {'batter': 'SR Watson',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 13,
#      'deliveries': [{'batter': 'Sachin Baby',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'Sachin Baby',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SR Watson',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'Sachin Baby',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'Sachin Baby',
#          'fielders': [{'name': 'MC Henriques'}]}]},
#       {'batter': 'SR Watson',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'STR Binny',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'STR Binny',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 14,
#      'deliveries': [{'batter': 'STR Binny',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SR Watson',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'STR Binny',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'STR Binny',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'STR Binny',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'STR Binny',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SR Watson',
#        'bowler': 'Rashid Khan',
#        'non_striker': 'STR Binny',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}}]},
#     {'over': 15,
#      'deliveries': [{'batter': 'STR Binny',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'STR Binny',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'STR Binny',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SR Watson',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'STR Binny',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'SR Watson',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'STR Binny',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'SR Watson',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'STR Binny',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 16,
#      'deliveries': [{'batter': 'SR Watson',
#        'bowler': 'B Kumar',
#        'non_striker': 'STR Binny',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'STR Binny',
#        'bowler': 'B Kumar',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SR Watson',
#        'bowler': 'B Kumar',
#        'non_striker': 'STR Binny',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'SR Watson',
#        'bowler': 'B Kumar',
#        'non_striker': 'STR Binny',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'STR Binny',
#        'bowler': 'B Kumar',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'STR Binny',
#          'fielders': [{'name': 'Yuvraj Singh'}]}]},
#       {'batter': 'S Aravind',
#        'bowler': 'B Kumar',
#        'non_striker': 'SR Watson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 17,
#      'deliveries': [{'batter': 'SR Watson',
#        'bowler': 'A Nehra',
#        'non_striker': 'S Aravind',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'SR Watson',
#        'bowler': 'A Nehra',
#        'non_striker': 'S Aravind',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'SR Watson',
#        'bowler': 'A Nehra',
#        'non_striker': 'S Aravind',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'SR Watson',
#          'fielders': [{'name': 'MC Henriques'}]}]},
#       {'batter': 'S Aravind',
#        'bowler': 'A Nehra',
#        'non_striker': 'TS Mills',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'bowled', 'player_out': 'S Aravind'}]},
#       {'batter': 'YS Chahal',
#        'bowler': 'A Nehra',
#        'non_striker': 'TS Mills',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'YS Chahal',
#        'bowler': 'A Nehra',
#        'non_striker': 'TS Mills',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 18,
#      'deliveries': [{'batter': 'TS Mills',
#        'bowler': 'B Kumar',
#        'extras': {'legbyes': 1},
#        'non_striker': 'YS Chahal',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'YS Chahal',
#        'bowler': 'B Kumar',
#        'non_striker': 'TS Mills',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'YS Chahal',
#        'bowler': 'B Kumar',
#        'non_striker': 'TS Mills',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TS Mills',
#        'bowler': 'B Kumar',
#        'non_striker': 'YS Chahal',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'TS Mills',
#        'bowler': 'B Kumar',
#        'non_striker': 'YS Chahal',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'TS Mills',
#          'fielders': [{'name': 'DA Warner'}]}]},
#       {'batter': 'YS Chahal',
#        'bowler': 'B Kumar',
#        'non_striker': 'A Choudhary',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 19,
#      'deliveries': [{'batter': 'YS Chahal',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'A Choudhary',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'YS Chahal',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'A Choudhary',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'A Choudhary',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'YS Chahal',
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'A Choudhary',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'YS Chahal',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'run out',
#          'player_out': 'YS Chahal',
#          'fielders': [{'name': 'CJ Jordan', 'substitute': True}]}]}]}],
#    'powerplays': [{'from': 0.1, 'to': 5.6, 'type': 'mandatory'}],
#    'target': {'overs': 20, 'runs': 208}}]}

# %%
#match_id

file.name.split('/')[1].split('.')[0]
# Out:
# '1082591'

# %%
data['innings'][1]['target']['runs']
# Out:
# 208
